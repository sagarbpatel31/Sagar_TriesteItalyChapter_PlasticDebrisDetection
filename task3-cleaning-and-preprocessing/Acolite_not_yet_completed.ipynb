# %%
import pandas as pd

# %%
updated_p = pd.read_csv('matched_s2_products.csv')

# %%
updated_p['product_id'].unique()
# Out:
# array(['S2A_MSIL1C_20170918T100021_N0500_R122_T32SPD_20231014T080243.SAFE',
#        'S2A_MSIL1C_20170928T100021_N0500_R122_T32SPD_20230912T173224.SAFE',
#        'S2A_MSIL1C_20170928T100021_N0500_R122_T32SNC_20230912T173224.SAFE',
#        ...,
#        'S2A_MSIL1C_20210811T101031_N0500_R022_T32TQQ_20230211T192458.SAFE',
#        'S2A_MSIL1C_20210821T101031_N0500_R022_T32TQQ_20230119T115533.SAFE',
#        'S2A_MSIL1C_20210821T101031_N0500_R022_T33TUK_20230119T115533.SAFE'],
#       dtype=object)

# %%
# !pip install hypercoast
# !pip install geopandas
# !pip install rasterio
# !pip install shapely
# Out:
# Requirement already satisfied: hypercoast in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (0.10.0)
# Requirement already satisfied: dask in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from hypercoast) (2025.3.0)
# Requirement already satisfied: earthaccess in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from hypercoast) (0.14.0)
# Requirement already satisfied: geopandas in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from hypercoast) (1.0.1)
# Requirement already satisfied: h5netcdf in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from hypercoast) (1.6.1)
# Requirement already satisfied: hvplot in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from hypercoast) (0.11.2)
# Requirement already satisfied: leafmap>=0.38.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from hypercoast) (0.43.3)
# Requirement already satisfied: localtileserver in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from hypercoast) (0.10.6)
# Requirement already satisfied: mapclassify in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from hypercoast) (2.8.1)
# Requirement already satisfied: netcdf4 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from hypercoast) (1.7.2)
# Requirement already satisfied: numpy in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from hypercoast) (1.26.1)
# Requirement already satisfied: psutil in /Users/navoditamathur/.local/lib/python3.11/site-packages (from hypercoast) (6.0.0)
# Requirement already satisfied: rioxarray in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from hypercoast) (0.18.2)
# Requirement already satisfied: s3fs in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from hypercoast) (2025.3.2)
# Requirement already satisfied: scikit-learn in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from hypercoast) (1.3.2)
# Requirement already satisfied: scipy in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from hypercoast) (1.11.3)
# Requirement already satisfied: xarray in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from hypercoast) (2025.3.1)
# Requirement already satisfied: anywidget in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from leafmap>=0.38.0->hypercoast) (0.9.18)
# Requirement already satisfied: bqplot in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from leafmap>=0.38.0->hypercoast) (0.12.44)
# Requirement already satisfied: colour in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from leafmap>=0.38.0->hypercoast) (0.1.5)
# Requirement already satisfied: duckdb in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from leafmap>=0.38.0->hypercoast) (1.2.1)
# Requirement already satisfied: folium in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from leafmap>=0.38.0->hypercoast) (0.19.5)
# Requirement already satisfied: gdown in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from leafmap>=0.38.0->hypercoast) (5.2.0)
# Requirement already satisfied: geojson in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from leafmap>=0.38.0->hypercoast) (3.2.0)
# Requirement already satisfied: ipyevents in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from leafmap>=0.38.0->hypercoast) (2.0.2)
# Requirement already satisfied: ipyfilechooser in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from leafmap>=0.38.0->hypercoast) (0.6.0)
# Requirement already satisfied: ipyleaflet in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from leafmap>=0.38.0->hypercoast) (0.19.2)
# Requirement already satisfied: ipyvuetify in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from leafmap>=0.38.0->hypercoast) (1.11.1)
# Requirement already satisfied: ipywidgets in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from leafmap>=0.38.0->hypercoast) (8.1.5)
# Requirement already satisfied: matplotlib in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from leafmap>=0.38.0->hypercoast) (3.8.1)
# Requirement already satisfied: pandas in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from leafmap>=0.38.0->hypercoast) (2.1.3)
# Requirement already satisfied: plotly in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from leafmap>=0.38.0->hypercoast) (6.0.1)
# Requirement already satisfied: pyshp in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from leafmap>=0.38.0->hypercoast) (2.3.1)
# Requirement already satisfied: pystac-client in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from leafmap>=0.38.0->hypercoast) (0.8.6)
# Requirement already satisfied: python-box in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from leafmap>=0.38.0->hypercoast) (7.3.2)
# Requirement already satisfied: scooby in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from leafmap>=0.38.0->hypercoast) (0.10.0)
# Requirement already satisfied: whiteboxgui in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from leafmap>=0.38.0->hypercoast) (2.3.0)
# Requirement already satisfied: xyzservices in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from leafmap>=0.38.0->hypercoast) (2025.1.0)
# Requirement already satisfied: click>=8.1 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from dask->hypercoast) (8.1.8)
# Requirement already satisfied: cloudpickle>=3.0.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from dask->hypercoast) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from dask->hypercoast) (2025.3.2)
# Requirement already satisfied: packaging>=20.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from dask->hypercoast) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from dask->hypercoast) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from dask->hypercoast) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from dask->hypercoast) (1.0.0)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from dask->hypercoast) (8.5.0)
# Requirement already satisfied: importlib-resources>=6.3.2 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from earthaccess->hypercoast) (6.5.2)
# Requirement already satisfied: multimethod>=1.8 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from earthaccess->hypercoast) (2.0)
# Requirement already satisfied: pqdm>=0.1 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from earthaccess->hypercoast) (0.2.0)
# Requirement already satisfied: python-cmr>=0.10.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from earthaccess->hypercoast) (0.13.0)
# Requirement already satisfied: requests>=2.26 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from earthaccess->hypercoast) (2.32.3)
# Requirement already satisfied: tinynetrc>=1.3.1 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from earthaccess->hypercoast) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/navoditamathur/.local/lib/python3.11/site-packages (from earthaccess->hypercoast) (4.12.2)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from s3fs->hypercoast) (2.21.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from s3fs->hypercoast) (3.11.13)
# Requirement already satisfied: pyogrio>=0.7.2 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from geopandas->hypercoast) (0.10.0)
# Requirement already satisfied: pyproj>=3.3.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from geopandas->hypercoast) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from geopandas->hypercoast) (2.1.0)
# Requirement already satisfied: h5py in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from h5netcdf->hypercoast) (3.10.0)
# Requirement already satisfied: bokeh>=3.1 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from hvplot->hypercoast) (3.7.2)
# Requirement already satisfied: colorcet>=2 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from hvplot->hypercoast) (3.1.0)
# Requirement already satisfied: holoviews>=1.19.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from hvplot->hypercoast) (1.20.2)
# Requirement already satisfied: panel>=1.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from hvplot->hypercoast) (1.6.2)
# Requirement already satisfied: param<3.0,>=1.12.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from hvplot->hypercoast) (2.2.0)
# Requirement already satisfied: flask<4,>=2.0.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from localtileserver->hypercoast) (3.1.0)
# Requirement already satisfied: Flask-Caching in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from localtileserver->hypercoast) (2.3.1)
# Requirement already satisfied: flask-cors in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from localtileserver->hypercoast) (5.0.1)
# Requirement already satisfied: flask-restx>=1.3.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from localtileserver->hypercoast) (1.3.0)
# Requirement already satisfied: rio-tiler in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from localtileserver->hypercoast) (7.6.0)
# Requirement already satisfied: rio-cogeo in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from localtileserver->hypercoast) (5.4.1)
# Requirement already satisfied: server-thread in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from localtileserver->hypercoast) (0.3.0)
# Requirement already satisfied: werkzeug in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from localtileserver->hypercoast) (3.1.3)
# Requirement already satisfied: networkx>=2.7 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from mapclassify->hypercoast) (3.2.1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from scikit-learn->hypercoast) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from scikit-learn->hypercoast) (3.2.0)
# Requirement already satisfied: cftime in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from netcdf4->hypercoast) (1.6.4.post1)
# Requirement already satisfied: certifi in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from netcdf4->hypercoast) (2023.7.22)
# Requirement already satisfied: rasterio>=1.3.7 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from rioxarray->hypercoast) (1.4.3)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->hypercoast) (0.12.0)
# Requirement already satisfied: botocore<1.37.2,>=1.37.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->hypercoast) (1.37.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/navoditamathur/.local/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->hypercoast) (2.9.0.post0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->hypercoast) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->hypercoast) (6.1.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->hypercoast) (1.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->hypercoast) (2.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->hypercoast) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->hypercoast) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->hypercoast) (1.5.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->hypercoast) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->hypercoast) (1.18.3)
# Requirement already satisfied: Jinja2>=2.9 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from bokeh>=3.1->hvplot->hypercoast) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from bokeh>=3.1->hvplot->hypercoast) (1.2.0)
# Requirement already satisfied: narwhals>=1.13 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from bokeh>=3.1->hvplot->hypercoast) (1.33.0)
# Requirement already satisfied: pillow>=7.1.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from bokeh>=3.1->hvplot->hypercoast) (10.1.0)
# Requirement already satisfied: tornado>=6.2 in /Users/navoditamathur/.local/lib/python3.11/site-packages (from bokeh>=3.1->hvplot->hypercoast) (6.4.1)
# Requirement already satisfied: itsdangerous>=2.2 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from flask<4,>=2.0.0->localtileserver->hypercoast) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from flask<4,>=2.0.0->localtileserver->hypercoast) (1.9.0)
# Requirement already satisfied: aniso8601>=0.82 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from flask-restx>=1.3.0->localtileserver->hypercoast) (10.0.0)
# Requirement already satisfied: jsonschema in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from flask-restx>=1.3.0->localtileserver->hypercoast) (4.23.0)
# Requirement already satisfied: pytz in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from flask-restx>=1.3.0->localtileserver->hypercoast) (2023.3.post1)
# Requirement already satisfied: pyviz-comms>=2.1 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from holoviews>=1.19.0->hvplot->hypercoast) (3.0.4)
# Requirement already satisfied: zipp>=3.20 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from importlib_metadata>=4.13.0->dask->hypercoast) (3.21.0)
# Requirement already satisfied: tzdata>=2022.1 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from pandas->leafmap>=0.38.0->hypercoast) (2023.3)
# Requirement already satisfied: bleach in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from panel>=1.0->hvplot->hypercoast) (4.1.0)
# Requirement already satisfied: linkify-it-py in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from panel>=1.0->hvplot->hypercoast) (2.0.3)
# Requirement already satisfied: markdown in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from panel>=1.0->hvplot->hypercoast) (3.5.1)
# Requirement already satisfied: markdown-it-py in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from panel>=1.0->hvplot->hypercoast) (3.0.0)
# Requirement already satisfied: mdit-py-plugins in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from panel>=1.0->hvplot->hypercoast) (0.4.2)
# Requirement already satisfied: tqdm in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from panel>=1.0->hvplot->hypercoast) (4.66.1)
# Requirement already satisfied: locket in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from partd>=1.4.0->dask->hypercoast) (1.0.0)
# Requirement already satisfied: bounded-pool-executor in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from pqdm>=0.1->earthaccess->hypercoast) (0.0.3)
# Requirement already satisfied: affine in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from rasterio>=1.3.7->rioxarray->hypercoast) (2.4.0)
# Requirement already satisfied: cligj>=0.5 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from rasterio>=1.3.7->rioxarray->hypercoast) (0.7.2)
# Requirement already satisfied: click-plugins in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from rasterio>=1.3.7->rioxarray->hypercoast) (1.1.1)
# Requirement already satisfied: pyparsing in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from rasterio>=1.3.7->rioxarray->hypercoast) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from requests>=2.26->earthaccess->hypercoast) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from requests>=2.26->earthaccess->hypercoast) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from requests>=2.26->earthaccess->hypercoast) (2.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from werkzeug->localtileserver->hypercoast) (2.1.1)
# Requirement already satisfied: psygnal>=0.8.1 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from anywidget->leafmap>=0.38.0->hypercoast) (0.12.0)
# Requirement already satisfied: comm>=0.1.3 in /Users/navoditamathur/.local/lib/python3.11/site-packages (from ipywidgets->leafmap>=0.38.0->hypercoast) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /Users/navoditamathur/.local/lib/python3.11/site-packages (from ipywidgets->leafmap>=0.38.0->hypercoast) (8.27.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/navoditamathur/.local/lib/python3.11/site-packages (from ipywidgets->leafmap>=0.38.0->hypercoast) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from ipywidgets->leafmap>=0.38.0->hypercoast) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from ipywidgets->leafmap>=0.38.0->hypercoast) (3.0.13)
# Requirement already satisfied: traittypes>=0.0.6 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from bqplot->leafmap>=0.38.0->hypercoast) (0.2.1)
# Requirement already satisfied: cachelib>=0.9.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from Flask-Caching->localtileserver->hypercoast) (0.13.0)
# Requirement already satisfied: branca>=0.6.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from folium->leafmap>=0.38.0->hypercoast) (0.8.1)
# Requirement already satisfied: beautifulsoup4 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from gdown->leafmap>=0.38.0->hypercoast) (4.12.2)
# Requirement already satisfied: filelock in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from gdown->leafmap>=0.38.0->hypercoast) (3.13.1)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from ipyleaflet->leafmap>=0.38.0->hypercoast) (0.19.2)
# Requirement already satisfied: ipyvue<2,>=1.7 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from ipyvuetify->leafmap>=0.38.0->hypercoast) (1.11.2)
# Requirement already satisfied: cycler>=0.10 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from matplotlib->leafmap>=0.38.0->hypercoast) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from matplotlib->leafmap>=0.38.0->hypercoast) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from matplotlib->leafmap>=0.38.0->hypercoast) (1.4.5)
# Requirement already satisfied: pystac>=1.10.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from pystac[validation]>=1.10.0->pystac-client->leafmap>=0.38.0->hypercoast) (1.12.2)
# Requirement already satisfied: morecantile<7.0,>=5.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from rio-cogeo->localtileserver->hypercoast) (6.2.0)
# Requirement already satisfied: pydantic~=2.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from rio-cogeo->localtileserver->hypercoast) (2.10.6)
# Requirement already satisfied: cachetools in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from rio-tiler->localtileserver->hypercoast) (5.3.2)
# Requirement already satisfied: color-operations in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from rio-tiler->localtileserver->hypercoast) (0.2.0)
# Requirement already satisfied: httpx in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from rio-tiler->localtileserver->hypercoast) (0.27.2)
# Requirement already satisfied: numexpr in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from rio-tiler->localtileserver->hypercoast) (2.10.2)
# Requirement already satisfied: uvicorn in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from server-thread->localtileserver->hypercoast) (0.34.0)
# Requirement already satisfied: ipytree in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from whiteboxgui->leafmap>=0.38.0->hypercoast) (0.2.2)
# Requirement already satisfied: whitebox in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from whiteboxgui->leafmap>=0.38.0->hypercoast) (2.3.6)
# Requirement already satisfied: decorator in /Users/navoditamathur/.local/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->leafmap>=0.38.0->hypercoast) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/navoditamathur/.local/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->leafmap>=0.38.0->hypercoast) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/navoditamathur/.local/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->leafmap>=0.38.0->hypercoast) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/navoditamathur/.local/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->leafmap>=0.38.0->hypercoast) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /Users/navoditamathur/.local/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->leafmap>=0.38.0->hypercoast) (2.18.0)
# Requirement already satisfied: stack-data in /Users/navoditamathur/.local/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->leafmap>=0.38.0->hypercoast) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/navoditamathur/.local/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->leafmap>=0.38.0->hypercoast) (4.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from pydantic~=2.0->rio-cogeo->localtileserver->hypercoast) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from pydantic~=2.0->rio-cogeo->localtileserver->hypercoast) (2.27.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from jsonschema->flask-restx>=1.3.0->localtileserver->hypercoast) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from jsonschema->flask-restx>=1.3.0->localtileserver->hypercoast) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from jsonschema->flask-restx>=1.3.0->localtileserver->hypercoast) (0.23.1)
# Requirement already satisfied: six>=1.5 in /Users/navoditamathur/.local/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore<3.0.0,>=2.5.4->s3fs->hypercoast) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from beautifulsoup4->gdown->leafmap>=0.38.0->hypercoast) (2.5)
# Requirement already satisfied: webencodings in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from bleach->panel>=1.0->hvplot->hypercoast) (0.5.1)
# Requirement already satisfied: anyio in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from httpx->rio-tiler->localtileserver->hypercoast) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from httpx->rio-tiler->localtileserver->hypercoast) (1.0.7)
# Requirement already satisfied: sniffio in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from httpx->rio-tiler->localtileserver->hypercoast) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from httpcore==1.*->httpx->rio-tiler->localtileserver->hypercoast) (0.14.0)
# Requirement already satisfied: uc-micro-py in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from linkify-it-py->panel>=1.0->hvplot->hypercoast) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from markdown-it-py->panel>=1.0->hvplot->hypercoast) (0.1.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from requests[socks]->gdown->leafmap>=0.38.0->hypercoast) (1.7.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/navoditamathur/.local/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->leafmap>=0.38.0->hypercoast) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/navoditamathur/.local/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->leafmap>=0.38.0->hypercoast) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/navoditamathur/.local/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->leafmap>=0.38.0->hypercoast) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/navoditamathur/.local/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->leafmap>=0.38.0->hypercoast) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/navoditamathur/.local/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->leafmap>=0.38.0->hypercoast) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/navoditamathur/.local/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->leafmap>=0.38.0->hypercoast) (0.2.3)
# Requirement already satisfied: geopandas in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from geopandas) (1.26.1)
# Requirement already satisfied: pyogrio>=0.7.2 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from geopandas) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from geopandas) (2.1.3)
# Requirement already satisfied: pyproj>=3.3.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from geopandas) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from geopandas) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/navoditamathur/.local/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: certifi in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from pyogrio>=0.7.2->geopandas) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /Users/navoditamathur/.local/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Requirement already satisfied: rasterio in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (1.4.3)
# Requirement already satisfied: affine in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from rasterio) (23.1.0)
# Requirement already satisfied: certifi in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from rasterio) (2023.7.22)
# Requirement already satisfied: click>=4.0 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from rasterio) (8.1.8)
# Requirement already satisfied: cligj>=0.5 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from rasterio) (1.26.1)
# Requirement already satisfied: click-plugins in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: pyparsing in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from rasterio) (3.1.1)
# Requirement already satisfied: shapely in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (2.1.0)
# Requirement already satisfied: numpy>=1.21 in /Users/navoditamathur/anaconda3/envs/ComputerVisionProject/lib/python3.11/site-packages (from shapely) (1.26.1)

# %%
updated_p[updated_p['product_id']=='S2A_MSIL1C_20170928T100021_N0500_R122_T32SPD_20230912T173224.SAFE']
# Out:
#    filament_id  lat_centroid  lon_centroid     dec_time        date  \
# 1         2001     34.930481     11.026350  2017.740763  2017-09-28
# 2         2002     34.895719     11.048051  2017.740763  2017-09-28
# 3         2003     34.782466     11.085260  2017.740763  2017-09-28
# 4         2004     34.695855     10.773533  2017.740763  2017-09-28
# 5         2005     34.526897     10.594494  2017.740763  2017-09-28
#
#                                           product_id  \
# 1  S2A_MSIL1C_20170928T100021_N0500_R122_T32SPD_2...
# 2  S2A_MSIL1C_20170928T100021_N0500_R122_T32SPD_2...
# 3  S2A_MSIL1C_20170928T100021_N0500_R122_T32SPD_2...
# 4  S2A_MSIL1C_20170928T100021_N0500_R122_T32SPD_2...
# 5  S2A_MSIL1C_20170928T100021_N0500_R122_T32SPD_2...
#
#                    datetime mgrs_tile
# 1  2017-09-28T10:11:08.261Z   Unknown
# 2  2017-09-28T10:11:08.261Z   Unknown
# 3  2017-09-28T10:11:08.261Z   Unknown
# 4  2017-09-28T10:11:08.261Z   Unknown
# 5  2017-09-28T10:11:08.261Z   Unknown

# %%
import shutil

src = "hypercoast_work/safe/S2A_MSIL1C_20170918T100021_N0500_R122_T32SPD_20231014T080243.SAFE.zip"
dst = "hypercoast_work/safe/"

shutil.unpack_archive(src, extract_dir=dst)

# %%
import pandas as pd
import os
import zipfile
import rasterio
from rasterio.windows import Window
from pathlib import Path
import hypercoast

# === Setup Paths ===
work_dir = Path("hypercoast_work")
input_dir = work_dir / "safe"
output_dir = work_dir / "output"
image_patch_dir = Path("geotiffs")
input_dir.mkdir(parents=True, exist_ok=True)
output_dir.mkdir(parents=True, exist_ok=True)
image_patch_dir.mkdir(parents=True, exist_ok=True)

# === Download ACOLITE (once) ===
acolite_dir = hypercoast.download_acolite(str(work_dir))

# === Group by unique S2 product ===
product_id = 'S2A_MSIL1C_20170918T100021_N0500_R122_T32SPD_20231014T080243.SAFE'
product_groups = updated_p.groupby("product_id")

for s2_product, group in product_groups:
    if s2_product != product_id:
        continue
    s2_product = s2_product.split('.')[0]
    print(f"\n🛰 Processing {s2_product} with {len(group)} filaments")

    safe_zip_path = input_dir / f"{s2_product}.zip"
    print(safe_zip_path)
    safe_folder_path = input_dir / f"{s2_product}.SAFE"

    # Step 1: Extract ZIP if not already
    if not safe_folder_path.exists():
        if safe_zip_path.exists():
            print(f"📦 Extracting {safe_zip_path}")
            try:
                with zipfile.ZipFile(safe_zip_path, 'r') as zip_ref:
                    zip_ref.extractall(input_dir)
            except Exception as e:
                print(f"❌ Failed to extract {safe_zip_path}: {e}")
                continue
        else:
            print(f"❌ ZIP file not found: {safe_zip_path}")
            continue
    else:
        print("✅ .SAFE folder exists.")

    # Step 2: Run ACOLITE once for this product
    try:
        print(f"🚀 Running ACOLITE...")
        hypercoast.run_acolite(
            acolite_dir=acolite_dir,
            input_file=str(safe_folder_path),
            out_dir=str(output_dir),
            l2w_parameters="Rrs_*",
            resolution=10,
            rgb_rhot=True,
            map_l2w=True
        )
    except Exception as e:
        print(f"❌ ACOLITE failed for {s2_product}: {e}")
        continue

    # Step 3: For each filament in this product, crop its patch
    band_path = output_dir / f"{s2_product}_Rrs_B04.tif"
    if not band_path.exists():
        print(f"⚠️ Missing ACOLITE output: {band_path}")
        continue

    for _, filament in group.iterrows():
        filament_id = filament["filament_id"]
        x_center = int(filament["x_centroid"])
        y_center = int(filament["y_centroid"])
        output_patch_path = image_patch_dir / f"filament_{filament_id}_image.tif"

        try:
            with rasterio.open(band_path) as src:
                window = Window(x_center - 128, y_center - 128, 256, 256)
                transform = src.window_transform(window)

                profile = src.meta.copy()
                profile.update({
                    "height": 256,
                    "width": 256,
                    "transform": transform
                })

                with rasterio.open(output_patch_path, "w", **profile) as dst:
                    dst.write(src.read(window=window))
            print(f"✅ Saved patch: {output_patch_path}")
        except Exception as e:
            print(f"❌ Failed to crop filament {filament_id}: {e}")
# Out:
# hypercoast_work/acolite_py_mac_20231023.0.tar.gz already exists. Skip downloading.
#
# 🛰 Processing S2A_MSIL1C_20170918T100021_N0500_R122_T32SPD_20231014T080243 with 4 filaments
# hypercoast_work/safe/S2A_MSIL1C_20170918T100021_N0500_R122_T32SPD_20231014T080243.zip
# ✅ .SAFE folder exists.
# 🚀 Running ACOLITE...
# osgeo/gdal.py:287: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
# acolite/sentinel2/l1_convert.py:417: RuntimeWarning: Mean of empty slice
# acolite/sentinel2/l1_convert.py:418: RuntimeWarning: Mean of empty slice
# Traceback (most recent call last):
#   File "launch_acolite.py", line 79, in <module>
#   File "launch_acolite.py", line 73, in launch_acolite
#   File "acolite/acolite/acolite_run.py", line 111, in acolite_run
#   File "acolite/acolite/acolite_l1r.py", line 72, in acolite_l1r
#   File "acolite/sentinel2/l1_convert.py", line 622, in l1_convert
#   File "acolite/output/nc_write.py", line 253, in nc_write
#   File "src/netCDF4/_netCDF4.pyx", line 5505, in netCDF4._netCDF4.Variable.__setitem__
#   File "src/netCDF4/_netCDF4.pyx", line 5788, in netCDF4._netCDF4.Variable._put
#   File "src/netCDF4/_netCDF4.pyx", line 2029, in netCDF4._netCDF4._ensure_nc_success
# RuntimeError: NetCDF: HDF error
# [36005] Failed to execute script 'launch_acolite' due to unhandled exception!
# Running ACOLITE processing - Generic Version 20231023.0
# Python - darwin - 3.11.6 | packaged by conda-forge | (main, Oct  3 2023, 10:54:14) [Clang 15.0.7 ]
# Platform - Darwin 23.1.0 - x86_64 - Darwin Kernel Version 23.1.0: Mon Oct  9 21:28:12 PDT 2023; root:xnu-10002.41.9~6/RELEASE_ARM64_T8103
# Run ID - 20250407_093845
# Identified hypercoast_work/safe/S2A_MSIL1C_20170918T100021_N0500_R122_T32SPD_20231014T080243.SAFE as Sentinel-2 type
# Starting conversion of 1 scenes
# Starting conversion of hypercoast_work/safe/S2A_MSIL1C_20170918T100021_N0500_R122_T32SPD_20231014T080243.SAFE
# Importing metadata from L1C_T32SPD_A011702_20170918T100023
# Reading per pixel geometry
# Computing band average per detector geometry
# Detector 4
# Detector 5
# Detector 6
# Detector 7
# Detector 8
# Detector 9
# Wrote raa (10980, 10980)
# Wrote vza (10980, 10980)
# Wrote sza (10980, 10980)
# Writing geolocation lon/lat
# (10980, 10980)
# Wrote lon
# (10980, 10980)
# ❌ ACOLITE failed for S2A_MSIL1C_20170918T100021_N0500_R122_T32SPD_20231014T080243: Command '['hypercoast_work/acolite_py_mac/dist/acolite/acolite', '--cli', '--settings', 'hypercoast_work/output/acolite_run_20250407_093845_settings_user.txt']' returned non-zero exit status 1.

# %%
import glob

jp2_files = glob.glob("hypercoast_work/safe/S2A_MSIL1C_20170918T100021_*.SAFE/GRANULE/*/IMG_DATA/*.jp2", recursive=True)
print(f"Found {len(jp2_files)} .jp2 files")
# Out:
# Found 14 .jp2 files

# %%
import rasterio
from rasterio.transform import from_origin
import numpy as np
from netCDF4 import Dataset
def extract_rrs_multiband_patch(nc_path, lat_center, lon_center, patch_size=256, output_path="rrs_patch.tif"):
    ds = Dataset(nc_path)
    lat = ds.variables["lat"][:]
    lon = ds.variables["lon"][:]

    # Get all available Rrs bands
    rrs_band_names = [k for k in ds.variables.keys() if k.startswith("Rrs_")]
    rrs_band_names.sort(key=lambda b: int(b.split("_")[1]))  # Sort by wavelength

    # Find center pixel
    lat_center = float(lat_center)  # Convert lat_center to float
    lon_center = float(lon_center)  # Convert lon_center to float


    dist = np.sqrt((lat - lat_center)[:, None]**2 + (lon - lon_center)[None, :]**2)
    y_center, x_center = np.unravel_index(np.argmin(dist), dist.shape)

    # Patch bounds
    half = patch_size // 2
    y_start, y_end = y_center - half, y_center + half
    x_start, x_end = x_center - half, x_center + half

    if y_start < 0 or x_start < 0 or y_end > lat.shape[0] or x_end > lon.shape[0]:
        print("❌ Patch goes out of bounds.")
        ds.close()
        return

    # Extract each band
    patch_stack = []
    for band in rrs_band_names:
        patch = ds.variables[band][y_start:y_end, x_start:x_end]
        patch_stack.append(patch)
    patch_stack = np.stack(patch_stack, axis=0)  # shape: (bands, H, W)

    # Geo info
    res_lat = np.abs(lat[1] - lat[0])
    res_lon = np.abs(lon[1] - lon[0])
    lat_ul = lat[y_start]
    lon_ul = lon[x_start]
    transform = from_origin(lon_ul, lat_ul, res_lon, res_lat)

    # Write GeoTIFF
    with rasterio.open(
        output_path,
        "w",
        driver="GTiff",
        height=patch_stack.shape[1],
        width=patch_stack.shape[2],
        count=patch_stack.shape[0],
        dtype=patch_stack.dtype,
        crs="EPSG:4326",
        transform=transform,
    ) as dst:
        for i in range(patch_stack.shape[0]):
            dst.write(patch_stack[i], i + 1)

    print(f"✅ Saved {len(rrs_band_names)}-band Rrs patch to {output_path}")
    ds.close()

# %%
product_id = 'S2A_MSIL1C_20170918T100021_N0500_R122_T32SPD_20231014T080243.SAFE'
product_groups = updated_p.groupby("product_id")

for s2_product, group in product_groups:
    if s2_product != product_id:
        continue
    for _, filament in group.iterrows():
        print(filament)
        filament_id = filament["filament_id"]
        x_center = int(filament["lat_centroid"])
        y_center = int(filament["lon_centroid"])

        extract_rrs_multiband_patch(
        "/content/hypercoast_work/output/S2A_MSI_2017_09_18_10_11_07_T32SPD_L2W.nc",
        lat_center= x_center,
        lon_center= y_center,
        patch_size=256,
        output_path= s2_product+"_"+str(group.lat_centroid)+"_"+str(group.lon_centroid,)+".tif"
        )
# Out:
# filament_id                                                  2000
# lat_centroid                                            34.376412
# lon_centroid                                            10.869906
# dec_time                                              2017.713357
# date                                                   2017-09-18
# product_id      S2A_MSIL1C_20170918T100021_N0500_R122_T32SPD_2...
# datetime                                 2017-09-18T10:11:07.848Z
# mgrs_tile                                                 Unknown
# Name: 0, dtype: object
