# %%
# !pip install sentinelhub
# !pip install tqdm
# !pip install netCDF4
# Out:
# Collecting sentinelhub
#   Downloading sentinelhub-3.11.1-py3-none-any.whl (249 kB)
#      |████████████████████████████████| 249 kB 6.8 MB/s eta 0:00:01
# Collecting aenum>=2.1.4
#   Downloading aenum-3.1.15-py3-none-any.whl (137 kB)
#      |████████████████████████████████| 137 kB 15.0 MB/s eta 0:00:01
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.9/site-packages (from sentinelhub) (8.0.4)
# Collecting typing-extensions>=4.5.0
#   Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 9.0 MB/s  eta 0:00:01
# Collecting dataclasses-json
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Collecting requests-oauthlib>=1.0.0
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: tifffile>=2020.9.30 in /opt/anaconda3/lib/python3.9/site-packages (from sentinelhub) (2021.7.2)
# Collecting utm
#   Downloading utm-0.8.1-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: tomli in /opt/anaconda3/lib/python3.9/site-packages (from sentinelhub) (1.2.2)
# Collecting tomli-w
#   Downloading tomli_w-1.2.0-py3-none-any.whl (6.7 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.9/site-packages (from sentinelhub) (1.21.5)
# Collecting oauthlib
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Collecting pillow>=9.2.0
#   Downloading pillow-11.2.1-cp39-cp39-macosx_10_10_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 8.2 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil in /opt/anaconda3/lib/python3.9/site-packages (from sentinelhub) (2.8.2)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.9/site-packages (from sentinelhub) (4.64.0)
# Requirement already satisfied: requests>=2.27.0 in /opt/anaconda3/lib/python3.9/site-packages (from sentinelhub) (2.27.1)
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.6.1-cp39-cp39-macosx_10_9_x86_64.whl (6.1 MB)
#      |████████████████████████████████| 6.1 MB 7.4 MB/s eta 0:00:01
# Collecting shapely
#   Downloading shapely-2.0.7-cp39-cp39-macosx_10_9_x86_64.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 7.5 MB/s eta 0:00:01
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.9/site-packages (from pyproj>=2.2.0->sentinelhub) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.27.0->sentinelhub) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.27.0->sentinelhub) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.27.0->sentinelhub) (3.3)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 13.5 MB/s eta 0:00:01
# Collecting typing-inspect<1,>=0.4.0
#   Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: packaging>=17.0 in /opt/anaconda3/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->sentinelhub) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from packaging>=17.0->marshmallow<4.0.0,>=3.18.0->dataclasses-json->sentinelhub) (3.0.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->sentinelhub) (0.4.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil->sentinelhub) (1.16.0)
# Installing collected packages: typing-extensions, typing-inspect, oauthlib, marshmallow, utm, tomli-w, shapely, requests-oauthlib, pyproj, pillow, dataclasses-json, aenum, sentinelhub
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.0.1
#     Uninstalling Pillow-9.0.1:
#       Successfully uninstalled Pillow-9.0.1
# Successfully installed aenum-3.1.15 dataclasses-json-0.6.7 marshmallow-3.26.1 oauthlib-3.2.2 pillow-11.2.1 pyproj-3.6.1 requests-oauthlib-2.0.0 sentinelhub-3.11.1 shapely-2.0.7 tomli-w-1.2.0 typing-extensions-4.13.2 typing-inspect-0.9.0 utm-0.8.1
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.9/site-packages (4.64.0)
# Collecting netCDF4
#   Downloading netcdf4-1.7.2.tar.gz (835 kB)
#      |████████████████████████████████| 835 kB 6.0 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/anaconda3/bin/python /opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /var/folders/rt/rb13g4xx0tl52vhbn2ycgmsc0000gn/T/tmpagpazt8k
#        cwd: /private/var/folders/rt/rb13g4xx0tl52vhbn2ycgmsc0000gn/T/pip-install-ykh7ng6a/netcdf4_aee87daee7674798a4da11d32ede7fed
#   Complete output (34 lines):
#   reading from setup.cfg...
#   Package hdf5 was not found in the pkg-config search path.
#   Perhaps you should add the directory containing `hdf5.pc'
#   to the PKG_CONFIG_PATH environment variable
#   No package 'hdf5' found
#       HDF5_DIR environment variable not set, checking some standard locations ..
#   checking /opt/anaconda3/include...
#   HDF5 library version: 1.10.6 headers found in /opt/anaconda3/include
#   HDF5 library version: 1.10.6 found in /opt/anaconda3
#   NETCDF4_DIR environment variable not set, checking standard locations..
#   checking /opt/anaconda3...
#   checking /opt/anaconda3/Library...
#   checking /Users/navoditamathur...
#   checking /usr/local...
#   checking /sw...
#   checking /opt...
#   checking /opt/local...
#   checking /opt/homebrew...
#   checking /usr...
#   Traceback (most recent call last):
#     File "/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 349, in <module>
#       main()
#     File "/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 331, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#     File "/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 117, in get_requires_for_build_wheel
#       return hook(config_settings)
#     File "/private/var/folders/rt/rb13g4xx0tl52vhbn2ycgmsc0000gn/T/pip-build-env-ukl995ca/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 334, in get_requires_for_build_wheel
#       return self._get_build_requires(config_settings, requirements=[])
#     File "/private/var/folders/rt/rb13g4xx0tl52vhbn2ycgmsc0000gn/T/pip-build-env-ukl995ca/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 304, in _get_build_requires
#       self.run_setup()
#     File "/private/var/folders/rt/rb13g4xx0tl52vhbn2ycgmsc0000gn/T/pip-build-env-ukl995ca/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 320, in run_setup
#       exec(code, locals())
#     File "<string>", line 292, in <module>
#   ValueError: did not find netCDF version 4 headers
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/71/ed/4d27fcfa40ebfdad3d2088a3de7ee48dbff7f35163e815ec1870d2a7398c/netcdf4-1.7.2.tar.gz#sha256=a4c6375540b19989896136943abb6d44850ff6f1fa7d3f063253b1ad3f8b7fce (from https://pypi.org/simple/netcdf4/) (requires-python:>=3.8). Command errored out with exit status 1: /opt/anaconda3/bin/python /opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /var/folders/rt/rb13g4xx0tl52vhbn2ycgmsc0000gn/T/tmpagpazt8k Check the logs for full command output.
#   Downloading netcdf4-1.7.1.post2.tar.gz (827 kB)
#      |████████████████████████████████| 827 kB 4.2 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/anaconda3/bin/python /opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /var/folders/rt/rb13g4xx0tl52vhbn2ycgmsc0000gn/T/tmp5c6d9j2v
#        cwd: /private/var/folders/rt/rb13g4xx0tl52vhbn2ycgmsc0000gn/T/pip-install-ykh7ng6a/netcdf4_bb14fce0b83b4edb9de39a041b3e8758
#   Complete output (34 lines):
#   reading from setup.cfg...
#   Package hdf5 was not found in the pkg-config search path.
#   Perhaps you should add the directory containing `hdf5.pc'
#   to the PKG_CONFIG_PATH environment variable
#   No package 'hdf5' found
#       HDF5_DIR environment variable not set, checking some standard locations ..
#   checking /opt/anaconda3/include...
#   HDF5 library version: 1.10.6 headers found in /opt/anaconda3/include
#   HDF5 library version: 1.10.6 found in /opt/anaconda3
#   NETCDF4_DIR environment variable not set, checking standard locations..
#   checking /opt/anaconda3...
#   checking /opt/anaconda3/Library...
#   checking /Users/navoditamathur...
#   checking /usr/local...
#   checking /sw...
#   checking /opt...
#   checking /opt/local...
#   checking /opt/homebrew...
#   checking /usr...
#   Traceback (most recent call last):
#     File "/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 349, in <module>
#       main()
#     File "/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 331, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#     File "/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 117, in get_requires_for_build_wheel
#       return hook(config_settings)
#     File "/private/var/folders/rt/rb13g4xx0tl52vhbn2ycgmsc0000gn/T/pip-build-env-hva52qok/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 334, in get_requires_for_build_wheel
#       return self._get_build_requires(config_settings, requirements=[])
#     File "/private/var/folders/rt/rb13g4xx0tl52vhbn2ycgmsc0000gn/T/pip-build-env-hva52qok/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 304, in _get_build_requires
#       self.run_setup()
#     File "/private/var/folders/rt/rb13g4xx0tl52vhbn2ycgmsc0000gn/T/pip-build-env-hva52qok/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 320, in run_setup
#       exec(code, locals())
#     File "<string>", line 292, in <module>
#   ValueError: did not find netCDF version 4 headers
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/51/9a/69022e4985b1994e463b5aefa4416c1061a1212fbcada84da35631c37813/netcdf4-1.7.1.post2.tar.gz#sha256=37d557e36654889d7020192bfb56f9d5f93894cb32997eb837ae586c538fd7b6 (from https://pypi.org/simple/netcdf4/) (requires-python:>=3.8). Command errored out with exit status 1: /opt/anaconda3/bin/python /opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /var/folders/rt/rb13g4xx0tl52vhbn2ycgmsc0000gn/T/tmp5c6d9j2v Check the logs for full command output.
#   Downloading netcdf4-1.7.1.post1.tar.gz (827 kB)
#      |████████████████████████████████| 827 kB 9.6 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/anaconda3/bin/python /opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /var/folders/rt/rb13g4xx0tl52vhbn2ycgmsc0000gn/T/tmp9yt947z6
#        cwd: /private/var/folders/rt/rb13g4xx0tl52vhbn2ycgmsc0000gn/T/pip-install-ykh7ng6a/netcdf4_214b4b014c484089949a55b94916f404
#   Complete output (34 lines):
#   reading from setup.cfg...
#   Package hdf5 was not found in the pkg-config search path.
#   Perhaps you should add the directory containing `hdf5.pc'
#   to the PKG_CONFIG_PATH environment variable
#   No package 'hdf5' found
#       HDF5_DIR environment variable not set, checking some standard locations ..
#   checking /opt/anaconda3/include...
#   HDF5 library version: 1.10.6 headers found in /opt/anaconda3/include
#   HDF5 library version: 1.10.6 found in /opt/anaconda3
#   NETCDF4_DIR environment variable not set, checking standard locations..
#   checking /opt/anaconda3...
#   checking /opt/anaconda3/Library...
#   checking /Users/navoditamathur...
#   checking /usr/local...
#   checking /sw...
#   checking /opt...
#   checking /opt/local...
#   checking /opt/homebrew...
#   checking /usr...
#   Traceback (most recent call last):
#     File "/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 349, in <module>
#       main()
#     File "/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 331, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#     File "/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 117, in get_requires_for_build_wheel
#       return hook(config_settings)
#     File "/private/var/folders/rt/rb13g4xx0tl52vhbn2ycgmsc0000gn/T/pip-build-env-mavyh9j_/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 334, in get_requires_for_build_wheel
#       return self._get_build_requires(config_settings, requirements=[])
#     File "/private/var/folders/rt/rb13g4xx0tl52vhbn2ycgmsc0000gn/T/pip-build-env-mavyh9j_/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 304, in _get_build_requires
#       self.run_setup()
#     File "/private/var/folders/rt/rb13g4xx0tl52vhbn2ycgmsc0000gn/T/pip-build-env-mavyh9j_/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 320, in run_setup
#       exec(code, locals())
#     File "<string>", line 292, in <module>
#   ValueError: did not find netCDF version 4 headers
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/4d/a2/a1cf9790177376209b8d4b3b2f1fb59157324cf60d3e84ced1b23b886ee2/netcdf4-1.7.1.post1.tar.gz#sha256=797f0b25d87827fc6821e415d9e15a2068604b18c3be62563e72682bcba76548 (from https://pypi.org/simple/netcdf4/) (requires-python:>=3.8). Command errored out with exit status 1: /opt/anaconda3/bin/python /opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /var/folders/rt/rb13g4xx0tl52vhbn2ycgmsc0000gn/T/tmp9yt947z6 Check the logs for full command output.
#   Downloading netCDF4-1.6.5-cp39-cp39-macosx_10_9_x86_64.whl (7.5 MB)
#      |████████████████████████████████| 7.5 MB 92 kB/s eta 0:00:012
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.9/site-packages (from netCDF4) (1.21.5)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/cftime/
# Collecting cftime
#   Downloading cftime-1.6.4.post1-cp39-cp39-macosx_10_9_x86_64.whl (233 kB)
#      |████████████████████████████████| 233 kB 52.7 MB/s eta 0:00:01
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.9/site-packages (from netCDF4) (2021.10.8)
# Installing collected packages: cftime, netCDF4
# Successfully installed cftime-1.6.4.post1 netCDF4-1.6.5

# %%
import os
import sys
import pandas as pd
import requests
import json
import datetime
from tqdm import tqdm
from sentinelhub import (SHConfig,
    DataCollection,
    SentinelHubCatalog,
    SentinelHubRequest,
    SentinelHubStatistical,
    BBox,
    bbox_to_dimensions,
    CRS,
    MimeType,
    Geometry,
)
import netCDF4 as nc
from netCDF4 import Dataset

# %%
import pandas as pd
from netCDF4 import Dataset
from datetime import datetime
import numpy as np
from shapely.geometry import Point, box

# ----------------------------------------
# 1. Define AOI
# ----------------------------------------
from shapely.geometry import box

aoi_list = [
    {
        'name': 'Po River Plume',
        'bbox': box(12.45, 44.825, 12.7, 45.055),  # [min_lon, min_lat, max_lon, max_lat]
    },
    {
        'name' : 'North East Corsica', # 'T32TNN'
        'bbox' : box(9.6, 42.95, 9.9, 43.155)
    },
    {
        'name': 'South East Calabria', # 'T33SXC'
        'bbox': box(16.5, 38.35, 16.755, 38.555)
    }
]


# ----------------------------------------
# 2. Load Excel file
# ----------------------------------------
excel_path = "/content/LM_centroids.xlsx"
df_excel = pd.read_excel(excel_path, engine='openpyxl')
df_excel['Formatted_time'] = pd.to_datetime(df_excel['Str_time'], format='%Y%m%dT%H%M%S')

# ----------------------------------------
# 3. Load NetCDF file
# ----------------------------------------
ds = Dataset('/content/drive/MyDrive/WASP_LW_SENT2_MED_L1C_B_201506_202109_10m_6y_NRT_v1.0.nc')

nc_times = ds.variables['s2_product'][:]  # e.g., b'S2A_MSIL1C_20180612T081021_...'
nc_lat = ds.variables['lat_centroid'][:]
nc_lon = ds.variables['lon_centroid'][:]
n_pixels_fil = ds.variables['n_pixels_fil'][:]
pixel_x = ds.variables['pixel_x'][:]          # shape: (N_filaments, 2563)
pixel_y = ds.variables['pixel_y'][:]
pixel_spec = ds.variables['pixel_spec'][:]    # shape: (N_filaments, 2563, 13)

# ----------------------------------------
# 4. Parse NetCDF times
# ----------------------------------------
def extract_datetime_from_product(product_str):
    str_time = product_str.data.tobytes().decode('utf-8').split('_')[2]
    return datetime.strptime(str_time, '%Y%m%dT%H%M%S')

nc_datetimes = [extract_datetime_from_product(p) for p in nc_times]

# ----------------------------------------
# 5. Match Excel to NetCDF annotations
# ----------------------------------------
matched_rows = []
index = 0

for _, row in df_excel.iterrows():
    excel_time = datetime.strptime(row['Str_time'], '%Y%m%dT%H%M%S')
    excel_lat = row['Latitude']
    excel_lon = row['Longitude']

    # Compute time & spatial difference
    time_diffs = [abs((excel_time - nc_time).days) for nc_time in nc_datetimes]
    spatial_dists = np.sqrt((excel_lat - nc_lat)**2 + (excel_lon - nc_lon)**2)

    # Valid candidates within ±3 days and 0.05° (≈5 km)
    valid_indices = [i for i in range(len(nc_datetimes))
                     if time_diffs[i] <= 3 and spatial_dists[i] <= 0.05]

    if valid_indices:
        best_idx = valid_indices[np.argmin([spatial_dists[i] for i in valid_indices])]
        n = n_pixels_fil[best_idx]

        matched_point = Point(nc_lon[best_idx], nc_lat[best_idx])
        aoi_label = None
        for aoi in aoi_list:
          if aoi['bbox'].contains(matched_point):
            aoi_label = aoi['name']
            break

        matched_rows.append({
            'index': index,
            'excel_datetime': excel_time,
            'excel_lat': excel_lat,
            'excel_lon': excel_lon,
            'matched_time': nc_datetimes[best_idx],
            'matched_lat': nc_lat[best_idx],
            'matched_lon': nc_lon[best_idx],
            'matched_s2_product': nc_times[best_idx].data.tobytes().decode('utf-8'),
            'match_distance_deg': spatial_dists[best_idx],
            'AOI': aoi_label,
            'tile_name': nc_times[best_idx].data.tobytes().decode('utf-8').split('_')[5],
            'pixel_x': pixel_x[best_idx, :n].tolist(),
            'pixel_y': pixel_y[best_idx, :n].tolist(),
            'pixel_spec': pixel_spec[best_idx, :n, :].tolist()
        })
    else:
        matched_rows.append({
            'index': index,
            'excel_datetime': excel_time,
            'excel_lat': excel_lat,
            'excel_lon': excel_lon,
            'matched_time': None,
            'matched_lat': None,
            'matched_lon': None,
            'matched_s2_product': None,
            'match_distance_deg': None,
            'AOI': None,
            'tile_name': None,
            'pixel_x': None,
            'pixel_y': None,
            'pixel_spec': None
        })

    index += 1

# ----------------------------------------
# 6. Save to CSV (or optionally Pickle)
# ----------------------------------------
df_matched = pd.DataFrame(matched_rows)
df_matched.to_csv("matched_annotations.csv", index=False)
print("✅ Matching complete. Results saved to matched_annotations.csv.")
# Out:
# ✅ Matching complete. Results saved to matched_annotations.csv.

# %%
import pandas as pd
df_matched = pd.read_csv('matched_annotations.csv')

# %%
tile_df = df_matched.loc[df_matched['AOI'].notna(), ['matched_lat', 'matched_lon', 'tile_name', 'AOI', 'matched_time']]

# %%
tile_df.groupby(['tile_name', 'AOI']).count()
# Out:
#                                matched_lat  matched_lon  matched_time
# tile_name AOI
# T32TNN    North East Corsica             2            2             2
# T32TQQ    Po River Plume               134          134           134
# T32TQR    Po River Plume                38           38            38
# T33SXC    South East Calabria           27           27            27
# T33TUK    Po River Plume               147          147           147

# %%
tile_df.groupby(['AOI', 'tile_name', 'matched_time']).count()
# Out:
#                                                    matched_lat  matched_lon
# AOI                 tile_name matched_time
# North East Corsica  T32TNN    2016-04-29 10:10:32            1            1
#                               2019-06-18 10:10:29            1            1
# Po River Plume      T32TQQ    2015-07-11 10:00:06            1            1
#                               2015-08-20 10:00:16            4            4
#                               2015-08-30 10:00:16            1            1
# ...                                                        ...          ...
# South East Calabria T33SXC    2016-11-26 09:43:32            7            7
#                               2018-10-07 09:40:31           14           14
#                               2018-11-06 09:42:01            4            4
#                               2019-03-31 09:40:39            1            1
#                               2020-08-12 09:40:39            1            1
#
# [166 rows x 2 columns]

# %%
time_df = df_matched.loc[df_matched['AOI'].notna(), ['tile_name', 'AOI', 'matched_time']]

# %%
time_df.groupby(['AOI', 'tile_name']).count()
# Out:
#                                matched_time
# AOI                 tile_name
# North East Corsica  T32TNN                2
# Po River Plume      T32TQQ              134
#                     T32TQR               38
#                     T33TUK              147
# South East Calabria T33SXC               27
