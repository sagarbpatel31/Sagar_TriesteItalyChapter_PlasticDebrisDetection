# %%
# !pip install sentinelsat
# !pip install pystac_client
# !pip install pystac
# !pip install netCDF4
# Out:
# Collecting sentinelsat
#   Downloading sentinelsat-1.2.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from sentinelsat) (2.32.3)
# Requirement already satisfied: click>=7.1 in /usr/local/lib/python3.11/dist-packages (from sentinelsat) (8.1.8)
# Collecting html2text (from sentinelsat)
#   Downloading html2text-2024.2.26.tar.gz (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting geojson>=2 (from sentinelsat)
#   Downloading geojson-3.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tqdm>=4.58 in /usr/local/lib/python3.11/dist-packages (from sentinelsat) (4.67.1)
# Collecting geomet (from sentinelsat)
#   Downloading geomet-1.1.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->sentinelsat) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->sentinelsat) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->sentinelsat) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->sentinelsat) (2025.1.31)
# Downloading sentinelsat-1.2.1-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 3.7 MB/s eta 0:00:00
# Downloading geojson-3.2.0-py3-none-any.whl (15 kB)
# Downloading geomet-1.1.0-py3-none-any.whl (31 kB)
# Building wheels for collected packages: html2text
#   Building wheel for html2text (setup.py) ... done
#   Created wheel for html2text: filename=html2text-2024.2.26-py3-none-any.whl size=33111 sha256=50ac3c9214142a4b5681cf2bcf3dfdf33f4e45fd29dccdefc3e92f9c6ca676fc
#   Stored in directory: /root/.cache/pip/wheels/23/58/7c/d9c8c4d924a1ac2b621add1b2c1d30b639629a33cfdfde6a45
# Successfully built html2text
# Installing collected packages: html2text, geomet, geojson, sentinelsat
# Successfully installed geojson-3.2.0 geomet-1.1.0 html2text-2024.2.26 sentinelsat-1.2.1
# Collecting pystac_client
#   Downloading pystac_client-0.8.6-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: requests>=2.28.2 in /usr/local/lib/python3.11/dist-packages (from pystac_client) (2.32.3)
# Collecting pystac>=1.10.0 (from pystac[validation]>=1.10.0->pystac_client)
#   Downloading pystac-1.12.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pystac_client) (2.8.2)
# Requirement already satisfied: jsonschema~=4.18 in /usr/local/lib/python3.11/dist-packages (from pystac[validation]>=1.10.0->pystac_client) (4.23.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pystac_client) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.28.2->pystac_client) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.28.2->pystac_client) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.28.2->pystac_client) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.28.2->pystac_client) (2025.1.31)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (0.24.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from referencing>=0.28.4->jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (4.13.0)
# Downloading pystac_client-0.8.6-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 1.8 MB/s eta 0:00:00
# Downloading pystac-1.12.2-py3-none-any.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.2/194.2 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: pystac, pystac_client
# Successfully installed pystac-1.12.2 pystac_client-0.8.6
# Requirement already satisfied: pystac in /usr/local/lib/python3.11/dist-packages (1.12.2)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from pystac) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7.0->pystac) (1.17.0)
# Collecting netCDF4
#   Downloading netCDF4-1.7.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting cftime (from netCDF4)
#   Downloading cftime-1.6.4.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from netCDF4) (2025.1.31)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from netCDF4) (2.0.2)
# Downloading netCDF4-1.7.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 61.5 MB/s eta 0:00:00
# Downloading cftime-1.6.4.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 61.7 MB/s eta 0:00:00
# Installing collected packages: cftime, netCDF4
# Successfully installed cftime-1.6.4.post1 netCDF4-1.7.2

# %%
config = SHConfig()
config.sh_client_id = "sh-d8cb7089-a727-46c1-962a-cc25356a21f8"
config.sh_client_secret = "1Ml18KecO9NRA0Wm1u8rh5REqUvQHO4R"
config.sh_token_url = "https://identity.dataspace.copernicus.eu/auth/realms/CDSE/protocol/openid-connect/token"
config.sh_base_url = "https://sh.dataspace.copernicus.eu"
config.save("cdse")

# %%
# Download Natural Earth dataset directly
# !unzip ne_110m_admin_0_countries.zip
# Out:
# Archive:  ne_110m_admin_0_countries.zip
#   inflating: ne_110m_admin_0_countries.README.html
#  extracting: ne_110m_admin_0_countries.VERSION.txt
#  extracting: ne_110m_admin_0_countries.cpg
#   inflating: ne_110m_admin_0_countries.dbf
#   inflating: ne_110m_admin_0_countries.prj
#   inflating: ne_110m_admin_0_countries.shp
#   inflating: ne_110m_admin_0_countries.shx

# %%
# !pip install geopandas ace_tools
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.11/dist-packages (1.0.1)
# Collecting ace_tools
#   Downloading ace_tools-0.0-py3-none-any.whl.metadata (300 bytes)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from geopandas) (2.0.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from geopandas) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from geopandas) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from geopandas) (2.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from pyogrio>=0.7.2->geopandas) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.17.0)
# Downloading ace_tools-0.0-py3-none-any.whl (1.1 kB)
# Installing collected packages: ace_tools
# Successfully installed ace_tools-0.0

# %%
import geopandas as gpd
from shapely.geometry import Polygon
import pandas as pd

# Define bounding boxes
# Change accordingly
AOI_BBOXES = {
    'Po_River_Plume':      [12.5, 44.8, 13.2, 45.2],
    'Northern_Corsica':    [8.5, 42.9, 9.2, 43.6],
    'South_East_Calabria': [16.5, 38.35, 16.755, 38.555],
    'Gulf_of_Genova':      [8.5, 43.7, 9.2, 44.2],
}

# Convert to polygons explicitly
aoi_data = []
for name, (minx, miny, maxx, maxy) in AOI_BBOXES.items():
    poly = Polygon([(minx, miny), (minx, maxy), (maxx, maxy), (maxx, miny)])
    aoi_data.append({"name": name, "geometry": poly})

aoi_gdf = gpd.GeoDataFrame(aoi_data, crs="EPSG:4326")

# Load land polygons using the downloaded file
land = gpd.read_file("ne_110m_admin_0_countries.shp")

# Check if AOIs intersect land
aoi_with_land = gpd.sjoin(aoi_gdf, land, how="left", predicate="intersects")

# Instead of directly using  continent and name_right which may not exist, use available columns.
# Inspect the columns in land using land.columns
# Choose appropriate columns and rename if needed
aoi_with_land_result = aoi_with_land[["name", "geometry", "ADMIN", "NAME"]].rename(
    columns={"ADMIN": "continent", "NAME": "intersecting_land"} # Replace ADMIN, NAME with actual column names from land
)


# Show result
print(aoi_with_land_result[["name", "intersecting_land", "continent"]])
# Out:
#                   name intersecting_land continent
# 0       Po_River_Plume               NaN       NaN
# 1     Northern_Corsica               NaN       NaN
# 2  South_East_Calabria               NaN       NaN
# 3       Gulf_of_Genova               NaN       NaN

# %%
from netCDF4 import Dataset
from datetime import datetime, timedelta
from sentinelhub import SentinelHubCatalog, SHConfig, BBox, CRS, DataCollection
import pandas as pd
import numpy as np

# === Load from .nc file ===
nc_path = "/content/drive/MyDrive/WASP_LW_SENT2_MED_L1C_B_201506_202109_10m_6y_NRT_v1.0.nc"
ds = Dataset(nc_path)

# === Extract fields from NetCDF ===
s2_products = ["".join(x).strip() for x in ds.variables["s2_product"][:].data.astype(str)]
lat_centroid = ds.variables["lat_centroid"][:]
lon_centroid = ds.variables["lon_centroid"][:]

# === Parse datetime from original product name ===
def get_datetime_from_s2_product(product):
    try:
        dt_str = product.split("_")[2]  # e.g., 20170918T100021
        return datetime.strptime(dt_str, "%Y%m%dT%H%M%S")
    except Exception:
        return None

# === Initialize Sentinel Hub Catalog ===
config = SHConfig('cdse')
catalog = SentinelHubCatalog(config=config)

# === Query updated product from SentinelHub ===
def find_updated_safe(lat, lon, dt):
    if dt is None:
        return None

    bbox = BBox([lon - 0.01, lat - 0.01, lon + 0.01, lat + 0.01], crs=CRS.WGS84)
    time_interval = (dt.strftime("%Y-%m-%d"), (dt + timedelta(days=1)).strftime("%Y-%m-%d"))

    results = list(
        catalog.search(
            collection=DataCollection.SENTINEL2_L1C,
            bbox=bbox,
            time=time_interval,
            fields={"include": ["id", "properties.datetime", "properties.mgrsTile"]},
            limit=1,
        )
    )

    if results:
        item = results[0]
        product_id = item["id"]
        acquisition_time = item["properties"]["datetime"]
        mgrs_tile = item["properties"].get("mgrsTile", "Unknown")

        return {
            "updated_product_id": product_id,
            "acquisition_datetime": acquisition_time,
            "mgrs_tile": mgrs_tile
        }

    return {"updated_product_id": None, "acquisition_datetime": None, "mgrs_tile": None}

# Define bounding boxes
AOI_BBOXES = {
    'Po_River_Plume':      [12.5, 44.8, 13.2, 45.2],
    'Northern_Corsica':    [8.5, 42.9, 9.2, 43.6],
    'South_East_Calabria': [16.5, 38.35, 16.755, 38.555],
    'Gulf_of_Genova':      [8.5, 43.7, 9.2, 44.2],
}

def valid_point(lat, lon):
   for name, (minx, miny, maxx, maxy) in AOI_BBOXES.items():
       if minx <= lon <= maxx and miny <= lat <= maxy:
           return True
   return False

# === Build the result table ===
rows = []
for i in range(len(s2_products)):
    original_id = s2_products[i]
    lat = lat_centroid[i]
    lon = lon_centroid[i]
    if not valid_point(lat, lon):
        continue
    dt = get_datetime_from_s2_product(original_id)
    updated_info = find_updated_safe(lat, lon, dt) or {}
    rows.append({
        "filament_id": i,
        "original_s2_product": original_id,
        "lat_centroid": lat,
        "lon_centroid": lon,
        **updated_info
    })

# === Save to CSV ===
df = pd.DataFrame(rows)
df.to_csv("updated_s2_products.csv", index=False)
print("✅ Saved: updated_s2_products.csv")
# Out:
# ✅ Saved: updated_s2_products.csv

# %%
len(df)
# Out:
# 966

# %%
df.head()
# Out:
#    filament_id                                original_s2_product  \
# 0         2798  S2A_MSIL1C_20170723T101031_N0205_R022_T32TMN_2...
# 1         2799  S2A_MSIL1C_20170921T101021_N0205_R022_T32TMN_2...
# 2         2802  S2A_MSIL1C_20180509T101031_N0206_R022_T32TMN_2...
# 3         2807  S2A_MSIL1C_20180323T102021_N0206_R065_T32TMN_2...
# 4         2808  S2A_MSIL1C_20180323T102021_N0206_R065_T32TMN_2...
#
#    lat_centroid  lon_centroid  \
# 0     43.264108      9.105954
# 1     43.255225      9.107647
# 2     43.240564      9.084905
# 3     42.905445      8.966524
# 4     42.904640      9.024241
#
#                                   updated_product_id  \
# 0  S2A_MSIL1C_20170723T101031_N0500_R022_T32TMN_2...
# 1  S2A_MSIL1C_20170921T101021_N0500_R022_T32TMN_2...
# 2  S2A_MSIL1C_20180509T101031_N0500_R022_T32TMN_2...
# 3  S2A_MSIL1C_20180323T102021_N0500_R065_T32TMN_2...
# 4  S2A_MSIL1C_20180323T102021_N0500_R065_T32TMN_2...
#
#        acquisition_datetime mgrs_tile
# 0  2017-07-23T10:19:06.461Z   Unknown
# 1  2017-09-21T10:19:00.545Z   Unknown
# 2  2018-05-09T10:19:07.746Z   Unknown
# 3  2018-03-23T10:28:58.753Z   Unknown
# 4  2018-03-23T10:28:58.753Z   Unknown

# %%
df['original_s2_product'].nunique()
# Out:
# 357

# %%
df['updated_product_id'].nunique()
# Out:
# 250

# %%
def match(new, old):
  mismatch = False
  old_tile_id = old.split('_')[5].strip()
  new_tile_id = new.split('_')[5].strip()
  print(old_tile_id, new_tile_id)
  if old_tile_id == new_tile_id:
      print("Tile ID matches")
  else:
      mismatch = True
  old_str_time = old.split('_')[2].strip()
  new_str_time = new.split('_')[2].strip()
  print(old_str_time, new_str_time)
  if old_str_time == new_str_time:
      print("Time matches")
  else:
      mismatch = True
  print(mismatch)
  return mismatch

# %%
df['mis_match'] = df.apply(lambda row: match(row['original_s2_product'], row['updated_product_id']), axis=1)
# Out:
# T32TMN T32TMN
# Tile ID matches
# 20170723T101031 20170723T101031
# Time matches
# False
# T32TMN T32TMN
# Tile ID matches
# 20170921T101021 20170921T101021
# Time matches
# False
# T32TMN T32TMN
# Tile ID matches
# 20180509T101031 20180509T101031
# Time matches
# False
# T32TMN T32TMN
# Tile ID matches
# 20180323T102021 20180323T102021
# Time matches
# False
# T32TMN T32TMN
# Tile ID matches
# 20180323T102021 20180323T102021
# Time matches
# False
# T32TMN T32TMN
# Tile ID matches
# 20180323T102021 20180323T102021
# Time matches
# False
# T32TMN T32TMN
# Tile ID matches
# 20200521T102031 20200521T102031
# Time matches
# False
# T32TMN T32TMN
# Tile ID matches
# 20200521T102031 20200521T102031
# Time matches
# False
# T32TMN T32TMN
# Tile ID matches
# 20200521T102031 20200521T102031
# Time matches
# False
# T32TMN T32TMN
# Tile ID matches
# 20201018T102041 20201018T102041
# Time matches
# False
# T32TMP T32TMP
# Tile ID matches
# 20170517T102031 20170517T102031
# Time matches
# False
# T32TMP T32TMP
# Tile ID matches
# 20170517T102031 20170517T102031
# Time matches
# False
# T32TMP T32TMP
# Tile ID matches
# 20170517T102031 20170517T102031
# Time matches
# False
# T32TMP T32TMP
# Tile ID matches
# 20170517T102031 20170517T102031
# Time matches
# False
# T32TMP T32TMP
# Tile ID matches
# 20170517T102031 20170517T102031
# Time matches
# False
# T32TMP T32TMP
# Tile ID matches
# 20170517T102031 20170517T102031
# Time matches
# False
# T32TMP T32TMP
# Tile ID matches
# 20170527T102031 20170527T102031
# Time matches
# False
# T32TMP T32TMP
# Tile ID matches
# 20170616T102021 20170616T102021
# Time matches
# False
# T32TMP T32TMP
# Tile ID matches
# 20180422T102031 20180422T102031
# Time matches
# False
# T32TMP T32TMP
# Tile ID matches
# 20180422T102031 20180422T102031
# Time matches
# False
# T32TMP T32TMP
# Tile ID matches
# 20200521T102031 20200521T102031
# Time matches
# False
# T32TMP T32TMP
# Tile ID matches
# 20200521T102031 20200521T102031
# Time matches
# False
# T32TMP T32TMP
# Tile ID matches
# 20200521T102031 20200521T102031
# Time matches
# False
# T32TMP T32TMP
# Tile ID matches
# 20200521T102031 20200521T102031
# Time matches
# False
# T32TMN T32TMP
# 20200521T102031 20200521T102031
# Time matches
# True
# T32TMN T32TMP
# 20200521T102031 20200521T102031
# Time matches
# True
# T32TMN T32TMP
# 20200521T102031 20200521T102031
# Time matches
# True
# T32TMN T32TMP
# 20200521T102031 20200521T102031
# Time matches
# True
# T32TMN T32TMP
# 20200521T102031 20200521T102031
# Time matches
# True
# T32TMP T32TMP
# Tile ID matches
# 20201018T102041 20201018T102041
# Time matches
# False
# T32TMP T32TMP
# Tile ID matches
# 20201018T102041 20201018T102041
# Time matches
# False
# T32TMP T32TMP
# Tile ID matches
# 20201018T102041 20201018T102041
# Time matches
# False
# T32TMP T32TMP
# Tile ID matches
# 20201018T102041 20201018T102041
# Time matches
# False
# T32TMP T32TMP
# Tile ID matches
# 20201018T102041 20201018T102041
# Time matches
# False
# T32TMP T32TMP
# Tile ID matches
# 20201018T102041 20201018T102041
# Time matches
# False
# T32TMP T32TMP
# Tile ID matches
# 20201018T102041 20201018T102041
# Time matches
# False
# T32TMP T32TMP
# Tile ID matches
# 20201018T102041 20201018T102041
# Time matches
# False
# T32TMP T32TMQ
# 20180422T102031 20180422T102031
# Time matches
# True
# T32TMN T32TNN
# 20170424T101031 20170424T101031
# Time matches
# True
# T32TNN T32TNN
# Tile ID matches
# 20170424T101031 20170424T101031
# Time matches
# False
# T32TNN T32TNN
# Tile ID matches
# 20170504T101031 20170504T101031
# Time matches
# False
# T32TMN T32TNN
# 20210317T102021 20210317T102021
# Time matches
# True
# T32TNP T32TNP
# Tile ID matches
# 20200521T102031 20200521T102031
# Time matches
# False
# T32TMP T32TNP
# 20201018T102041 20201018T102041
# Time matches
# True
# T32TMP T32TNP
# 20201018T102041 20201018T102041
# Time matches
# True
# T32TMN T32TNP
# 20210317T102021 20210317T102021
# Time matches
# True
# T32TQQ T32TQQ
# Tile ID matches
# 20160429T101032 20160429T101032
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160618T101032 20160618T101032
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160618T101032 20160618T101032
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160827T101022 20160827T101022
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160926T101022 20160926T101022
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160926T101022 20160926T101022
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20161006T101022 20161006T101022
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20170325T101021 20170325T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20170325T101021 20170325T101021
# Time matches
# False
# T33TUK T32TQQ
# 20170921T101021 20170921T101021
# Time matches
# True
# T33TUK T32TQQ
# 20170921T101021 20170921T101021
# Time matches
# True
# T32TQQ T32TQQ
# Tile ID matches
# 20170921T101021 20170921T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20170921T101021 20170921T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20170921T101021 20170921T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20170921T101021 20170921T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20170921T101021 20170921T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20170921T101021 20170921T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20170921T101021 20170921T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20170921T101021 20170921T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180906T101021 20180906T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180906T101021 20180906T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180916T101021 20180916T101021
# Time matches
# False
# T33TUK T32TQQ
# 20190213T101131 20190213T101131
# Time matches
# True
# T32TQQ T32TQQ
# Tile ID matches
# 20190213T101131 20190213T101131
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190213T101131 20190213T101131
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190213T101131 20190213T101131
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190213T101131 20190213T101131
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190213T101131 20190213T101131
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190213T101131 20190213T101131
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190315T101021 20190315T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190315T101021 20190315T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190325T101021 20190325T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190325T101021 20190325T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190325T101021 20190325T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190723T101031 20190723T101031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190723T101031 20190723T101031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20191011T101031 20191011T101031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20191011T101031 20191011T101031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200319T101021 20200319T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200319T101021 20200319T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200816T101031 20200816T101031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200816T101031 20200816T101031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200826T101031 20200826T101031
# Time matches
# False
# T33TUK T32TQQ
# 20200905T101031 20200905T101031
# Time matches
# True
# T32TQQ T32TQQ
# Tile ID matches
# 20200905T101031 20200905T101031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200905T101031 20200905T101031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200905T101031 20200905T101031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200905T101031 20200905T101031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200905T101031 20200905T101031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200905T101031 20200905T101031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200905T101031 20200905T101031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200905T101031 20200905T101031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200915T101031 20200915T101031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200915T101031 20200915T101031
# Time matches
# False
# T33TUK T32TQQ
# 20210324T101021 20210324T101021
# Time matches
# True
# T32TQQ T32TQQ
# Tile ID matches
# 20210324T101021 20210324T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210324T101021 20210324T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210324T101021 20210324T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210324T101021 20210324T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210324T101021 20210324T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210324T101021 20210324T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210324T101021 20210324T101021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20150711T100006 20150711T100006
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20150711T100006 20150711T100006
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20150820T100016 20150820T100016
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20150820T100016 20150820T100016
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20150820T100016 20150820T100016
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20150820T100016 20150820T100016
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20150830T100016 20150830T100016
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20150830T100016 20150830T100016
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160506T100032 20160506T100032
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160506T100032 20160506T100032
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160605T100032 20160605T100032
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160605T100032 20160605T100032
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160605T100032 20160605T100032
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160605T100032 20160605T100032
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160804T100032 20160804T100032
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160804T100032 20160804T100032
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160804T100032 20160804T100032
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160804T100032 20160804T100032
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160804T100032 20160804T100032
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160804T100032 20160804T100032
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160804T100032 20160804T100032
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160804T100032 20160804T100032
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160804T100032 20160804T100032
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160814T100032 20160814T100032
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160824T100032 20160824T100032
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20160913T100022 20160913T100022
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20170421T100031 20170421T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20170521T100031 20170521T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20170521T100031 20170521T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20170521T100031 20170521T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180426T100031 20180426T100031
# Time matches
# False
# T33TUK T32TQQ
# 20180516T100031 20180516T100031
# Time matches
# True
# T32TQQ T32TQQ
# Tile ID matches
# 20180516T100031 20180516T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180516T100031 20180516T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180516T100031 20180516T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180516T100031 20180516T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180516T100031 20180516T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180516T100031 20180516T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180516T100031 20180516T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180516T100031 20180516T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180526T100031 20180526T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180526T100031 20180526T100031
# Time matches
# False
# T33TUK T32TQQ
# 20180705T100031 20180705T100031
# Time matches
# True
# T33TUK T32TQQ
# 20180705T100031 20180705T100031
# Time matches
# True
# T32TQQ T32TQQ
# Tile ID matches
# 20180705T100031 20180705T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180705T100031 20180705T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180705T100031 20180705T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180705T100031 20180705T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180705T100031 20180705T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180705T100031 20180705T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180705T100031 20180705T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180705T100031 20180705T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180705T100031 20180705T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180705T100031 20180705T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180705T100031 20180705T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180804T100031 20180804T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180824T100031 20180824T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180824T100031 20180824T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180824T100031 20180824T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180824T100031 20180824T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180824T100031 20180824T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180923T100021 20180923T100021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20181003T100021 20181003T100021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20181003T100021 20181003T100021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20181003T100021 20181003T100021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190302T100021 20190302T100021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190302T100021 20190302T100021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190312T100021 20190312T100021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190501T100031 20190501T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190531T100031 20190531T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190531T100031 20190531T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190531T100031 20190531T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190531T100031 20190531T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190531T100031 20190531T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190620T100031 20190620T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190730T100031 20190730T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190809T100031 20190809T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190819T100031 20190819T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190819T100031 20190819T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190819T100031 20190819T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190819T100031 20190819T100031
# Time matches
# False
# T33TUK T32TQQ
# 20191008T100031 20191008T100031
# Time matches
# True
# T33TUK T32TQQ
# 20200316T100021 20200316T100021
# Time matches
# True
# T32TQQ T32TQQ
# Tile ID matches
# 20200316T100021 20200316T100021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200316T100021 20200316T100021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200316T100021 20200316T100021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200525T100031 20200525T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200525T100031 20200525T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200525T100031 20200525T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200525T100031 20200525T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200525T100031 20200525T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200525T100031 20200525T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200525T100031 20200525T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200902T100031 20200902T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200902T100031 20200902T100031
# Time matches
# False
# T33TUK T32TQQ
# 20200912T100031 20200912T100031
# Time matches
# True
# T32TQQ T32TQQ
# Tile ID matches
# 20200912T100031 20200912T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20201111T100241 20201111T100241
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20201111T100241 20201111T100241
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20201111T100241 20201111T100241
# Time matches
# False
# T33TUK T32TQQ
# 20210301T100031 20210301T100031
# Time matches
# True
# T32TQQ T32TQQ
# Tile ID matches
# 20210301T100031 20210301T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210301T100031 20210301T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210420T100021 20210420T100021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210420T100021 20210420T100021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210420T100021 20210420T100021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210420T100021 20210420T100021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210420T100021 20210420T100021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210420T100021 20210420T100021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210420T100021 20210420T100021
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210420T100021 20210420T100021
# Time matches
# False
# T33TUK T32TQQ
# 20210520T100031 20210520T100031
# Time matches
# True
# T33TUK T32TQQ
# 20210520T100031 20210520T100031
# Time matches
# True
# T33TUK T32TQQ
# 20210520T100031 20210520T100031
# Time matches
# True
# T32TQQ T32TQQ
# Tile ID matches
# 20210520T100031 20210520T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210520T100031 20210520T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210520T100031 20210520T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210520T100031 20210520T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210520T100031 20210520T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210520T100031 20210520T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210520T100031 20210520T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210520T100031 20210520T100031
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210520T100031 20210520T100031
# Time matches
# False
# T32TQQ T32TQR
# 20150813T101026 20150813T101026
# Time matches
# True
# T32TQQ T32TQR
# 20150912T101403 20150912T101403
# Time matches
# True
# T32TQQ T32TQR
# 20150912T101403 20150912T101403
# Time matches
# True
# T32TQR T32TQR
# Tile ID matches
# 20170921T101021 20170921T101021
# Time matches
# False
# T32TQQ T32TQR
# 20170921T101021 20170921T101021
# Time matches
# True
# T32TQQ T32TQR
# 20170921T101021 20170921T101021
# Time matches
# True
# T32TQQ T32TQR
# 20170921T101021 20170921T101021
# Time matches
# True
# T32TQR T32TQR
# Tile ID matches
# 20180906T101021 20180906T101021
# Time matches
# False
# T32TQR T32TQR
# Tile ID matches
# 20180906T101021 20180906T101021
# Time matches
# False
# T32TQR T32TQR
# Tile ID matches
# 20180906T101021 20180906T101021
# Time matches
# False
# T32TQR T32TQR
# Tile ID matches
# 20180906T101021 20180906T101021
# Time matches
# False
# T32TQQ T32TQR
# 20180916T101021 20180916T101021
# Time matches
# True
# T32TQQ T32TQR
# 20180916T101021 20180916T101021
# Time matches
# True
# T32TQR T32TQR
# Tile ID matches
# 20190213T101131 20190213T101131
# Time matches
# False
# T33TUK T32TQR
# 20190213T101131 20190213T101131
# Time matches
# True
# T32TQQ T32TQR
# 20190213T101131 20190213T101131
# Time matches
# True
# T32TQQ T32TQR
# 20190213T101131 20190213T101131
# Time matches
# True
# T32TQQ T32TQR
# 20190213T101131 20190213T101131
# Time matches
# True
# T32TQQ T32TQR
# 20190213T101131 20190213T101131
# Time matches
# True
# T32TQQ T32TQR
# 20190723T101031 20190723T101031
# Time matches
# True
# T32TQQ T32TQR
# 20200319T101021 20200319T101021
# Time matches
# True
# T33TUK T32TQR
# 20200617T101031 20200617T101031
# Time matches
# True
# T32TQQ T32TQR
# 20200816T101031 20200816T101031
# Time matches
# True
# T32TQQ T32TQR
# 20200816T101031 20200816T101031
# Time matches
# True
# T32TQR T32TQR
# Tile ID matches
# 20200905T101031 20200905T101031
# Time matches
# False
# T32TQQ T32TQR
# 20200905T101031 20200905T101031
# Time matches
# True
# T32TQQ T32TQR
# 20200905T101031 20200905T101031
# Time matches
# True
# T32TQQ T32TQR
# 20210324T101021 20210324T101021
# Time matches
# True
# T32TQQ T32TQR
# 20210324T101021 20210324T101021
# Time matches
# True
# T32TQQ T32TQR
# 20210324T101021 20210324T101021
# Time matches
# True
# T32TQQ T32TQR
# 20210324T101021 20210324T101021
# Time matches
# True
# T32TQQ T32TQR
# 20150820T100016 20150820T100016
# Time matches
# True
# T32TQR T32TQR
# Tile ID matches
# 20150830T100016 20150830T100016
# Time matches
# False
# T33TUK T32TQR
# 20150830T100016 20150830T100016
# Time matches
# True
# T32TQQ T32TQR
# 20150830T100016 20150830T100016
# Time matches
# True
# T32TQQ T32TQR
# 20150830T100016 20150830T100016
# Time matches
# True
# T32TQQ T32TQR
# 20150830T100016 20150830T100016
# Time matches
# True
# T32TQR T32TQR
# Tile ID matches
# 20160506T100032 20160506T100032
# Time matches
# False
# T32TQQ T32TQR
# 20160605T100032 20160605T100032
# Time matches
# True
# T32TQQ T32TQR
# 20160804T100032 20160804T100032
# Time matches
# True
# T32TQQ T32TQR
# 20160814T100032 20160814T100032
# Time matches
# True
# T32TQQ T32TQR
# 20160814T100032 20160814T100032
# Time matches
# True
# T32TQQ T32TQR
# 20160814T100032 20160814T100032
# Time matches
# True
# T32TQQ T32TQR
# 20160923T100022 20160923T100022
# Time matches
# True
# T32TQQ T32TQR
# 20160923T100022 20160923T100022
# Time matches
# True
# T32TQR T32TQR
# Tile ID matches
# 20170312T100021 20170312T100021
# Time matches
# False
# T32TQR T32TQR
# Tile ID matches
# 20170312T100021 20170312T100021
# Time matches
# False
# T32TQQ T32TQR
# 20170312T100021 20170312T100021
# Time matches
# True
# T32TQQ T32TQR
# 20171008T100031 20171008T100031
# Time matches
# True
# T32TQQ T32TQR
# 20180516T100031 20180516T100031
# Time matches
# True
# T32TQQ T32TQR
# 20180526T100031 20180526T100031
# Time matches
# True
# T32TQR T32TQR
# Tile ID matches
# 20180605T100031 20180605T100031
# Time matches
# False
# T32TQR T32TQR
# Tile ID matches
# 20180705T100031 20180705T100031
# Time matches
# False
# T32TQR T32TQR
# Tile ID matches
# 20180705T100031 20180705T100031
# Time matches
# False
# T32TQQ T32TQR
# 20180705T100031 20180705T100031
# Time matches
# True
# T32TQQ T32TQR
# 20180705T100031 20180705T100031
# Time matches
# True
# T32TQQ T32TQR
# 20180705T100031 20180705T100031
# Time matches
# True
# T32TQQ T32TQR
# 20180705T100031 20180705T100031
# Time matches
# True
# T32TQQ T32TQR
# 20180705T100031 20180705T100031
# Time matches
# True
# T32TQQ T32TQR
# 20180705T100031 20180705T100031
# Time matches
# True
# T33TUK T32TQR
# 20180804T100031 20180804T100031
# Time matches
# True
# T32TQR T32TQR
# Tile ID matches
# 20190531T100031 20190531T100031
# Time matches
# False
# T32TQR T32TQR
# Tile ID matches
# 20190531T100031 20190531T100031
# Time matches
# False
# T32TQR T32TQR
# Tile ID matches
# 20190531T100031 20190531T100031
# Time matches
# False
# T32TQQ T32TQR
# 20190531T100031 20190531T100031
# Time matches
# True
# T32TQQ T32TQR
# 20190531T100031 20190531T100031
# Time matches
# True
# T32TQR T32TQR
# Tile ID matches
# 20190630T100031 20190630T100031
# Time matches
# False
# T33TUK T32TQR
# 20190720T100031 20190720T100031
# Time matches
# True
# T32TQR T32TQR
# Tile ID matches
# 20190819T100031 20190819T100031
# Time matches
# False
# T32TQR T32TQR
# Tile ID matches
# 20190819T100031 20190819T100031
# Time matches
# False
# T33TUK T32TQR
# 20190819T100031 20190819T100031
# Time matches
# True
# T32TQR T32TQR
# Tile ID matches
# 20200525T100031 20200525T100031
# Time matches
# False
# T32TQQ T32TQR
# 20200525T100031 20200525T100031
# Time matches
# True
# T32TQQ T32TQR
# 20200525T100031 20200525T100031
# Time matches
# True
# T32TQQ T32TQR
# 20200525T100031 20200525T100031
# Time matches
# True
# T32TQQ T32TQR
# 20200525T100031 20200525T100031
# Time matches
# True
# T32TQQ T32TQR
# 20200525T100031 20200525T100031
# Time matches
# True
# T32TQR T32TQR
# Tile ID matches
# 20200823T100031 20200823T100031
# Time matches
# False
# T32TQQ T32TQR
# 20210420T100021 20210420T100021
# Time matches
# True
# T33TUK T32TQR
# 20210520T100031 20210520T100031
# Time matches
# True
# T33TUK T32TQR
# 20210520T100031 20210520T100031
# Time matches
# True
# T32TQQ T32TQR
# 20210520T100031 20210520T100031
# Time matches
# True
# T33SXC T33SXC
# Tile ID matches
# 20161126T094332 20161126T094332
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20161126T094332 20161126T094332
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20161126T094332 20161126T094332
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20161126T094332 20161126T094332
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20161126T094332 20161126T094332
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20161126T094332 20161126T094332
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20161126T094332 20161126T094332
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20181007T094031 20181007T094031
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20181007T094031 20181007T094031
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20181007T094031 20181007T094031
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20181007T094031 20181007T094031
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20181007T094031 20181007T094031
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20181007T094031 20181007T094031
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20181007T094031 20181007T094031
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20181007T094031 20181007T094031
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20181007T094031 20181007T094031
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20181007T094031 20181007T094031
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20181007T094031 20181007T094031
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20181007T094031 20181007T094031
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20181007T094031 20181007T094031
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20181007T094031 20181007T094031
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20181106T094201 20181106T094201
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20181106T094201 20181106T094201
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20181106T094201 20181106T094201
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20181106T094201 20181106T094201
# Time matches
# False
# T32TQQ T33TUK
# 20150912T101403 20150912T101403
# Time matches
# True
# T32TQQ T33TUK
# 20160618T101032 20160618T101032
# Time matches
# True
# T32TQQ T33TUK
# 20160618T101032 20160618T101032
# Time matches
# True
# T32TQQ T33TUK
# 20160618T101032 20160618T101032
# Time matches
# True
# T32TQQ T33TUK
# 20160817T101032 20160817T101032
# Time matches
# True
# T32TQQ T33TUK
# 20160827T101022 20160827T101022
# Time matches
# True
# T32TQQ T33TUK
# 20160926T101022 20160926T101022
# Time matches
# True
# T32TQQ T33TUK
# 20160926T101022 20160926T101022
# Time matches
# True
# T32TQQ T33TUK
# 20160926T101022 20160926T101022
# Time matches
# True
# T32TQQ T33TUK
# 20160926T101022 20160926T101022
# Time matches
# True
# T32TQQ T33TUK
# 20161006T101022 20161006T101022
# Time matches
# True
# T32TQQ T33TUK
# 20161006T101022 20161006T101022
# Time matches
# True
# T32TQQ T33TUK
# 20170325T101021 20170325T101021
# Time matches
# True
# T32TQQ T33TUK
# 20170325T101021 20170325T101021
# Time matches
# True
# T32TQQ T33TUK
# 20170325T101021 20170325T101021
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20170404T101021 20170404T101021
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20170404T101021 20170404T101021
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20170404T101021 20170404T101021
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20170404T101021 20170404T101021
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20170404T101021 20170404T101021
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20170404T101021 20170404T101021
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20170404T101021 20170404T101021
# Time matches
# False
# T32TQQ T33TUK
# 20170921T101021 20170921T101021
# Time matches
# True
# T32TQQ T33TUK
# 20170921T101021 20170921T101021
# Time matches
# True
# T32TQQ T33TUK
# 20170921T101021 20170921T101021
# Time matches
# True
# T32TQQ T33TUK
# 20170921T101021 20170921T101021
# Time matches
# True
# T32TQQ T33TUK
# 20170921T101021 20170921T101021
# Time matches
# True
# T32TQQ T33TUK
# 20170921T101021 20170921T101021
# Time matches
# True
# T32TQQ T33TUK
# 20170921T101021 20170921T101021
# Time matches
# True
# T32TQQ T33TUK
# 20170921T101021 20170921T101021
# Time matches
# True
# T32TQQ T33TUK
# 20170921T101021 20170921T101021
# Time matches
# True
# T32TQQ T33TUK
# 20170921T101021 20170921T101021
# Time matches
# True
# T32TQQ T33TUK
# 20170921T101021 20170921T101021
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20180906T101021 20180906T101021
# Time matches
# False
# T32TQQ T33TUK
# 20180906T101021 20180906T101021
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20180906T101021 20180906T101021
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20180906T101021 20180906T101021
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20180906T101021 20180906T101021
# Time matches
# False
# T32TQQ T33TUK
# 20180906T101021 20180906T101021
# Time matches
# True
# T32TQQ T33TUK
# 20180916T101021 20180916T101021
# Time matches
# True
# T32TQQ T33TUK
# 20180916T101021 20180916T101021
# Time matches
# True
# T32TQQ T33TUK
# 20180916T101021 20180916T101021
# Time matches
# True
# T32TQQ T33TUK
# 20180916T101021 20180916T101021
# Time matches
# True
# T32TQQ T33TUK
# 20190213T101131 20190213T101131
# Time matches
# True
# T32TQQ T33TUK
# 20190213T101131 20190213T101131
# Time matches
# True
# T32TQQ T33TUK
# 20190213T101131 20190213T101131
# Time matches
# True
# T32TQQ T33TUK
# 20190213T101131 20190213T101131
# Time matches
# True
# T32TQQ T33TUK
# 20190213T101131 20190213T101131
# Time matches
# True
# T32TQQ T33TUK
# 20190213T101131 20190213T101131
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20190213T101131 20190213T101131
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20190213T101131 20190213T101131
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20190213T101131 20190213T101131
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20190213T101131 20190213T101131
# Time matches
# False
# T32TQQ T33TUK
# 20190213T101131 20190213T101131
# Time matches
# True
# T32TQQ T33TUK
# 20190213T101131 20190213T101131
# Time matches
# True
# T32TQQ T33TUK
# 20190315T101021 20190315T101021
# Time matches
# True
# T32TQQ T33TUK
# 20190315T101021 20190315T101021
# Time matches
# True
# T32TQQ T33TUK
# 20190325T101021 20190325T101021
# Time matches
# True
# T32TQQ T33TUK
# 20190325T101021 20190325T101021
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20190524T101031 20190524T101031
# Time matches
# False
# T32TQQ T33TUK
# 20190723T101031 20190723T101031
# Time matches
# True
# T32TQQ T33TUK
# 20190723T101031 20190723T101031
# Time matches
# True
# T32TQQ T33TUK
# 20190723T101031 20190723T101031
# Time matches
# True
# T32TQQ T33TUK
# 20191011T101031 20191011T101031
# Time matches
# True
# T32TQQ T33TUK
# 20200319T101021 20200319T101021
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20200319T101021 20200319T101021
# Time matches
# False
# T32TQQ T33TUK
# 20200319T101021 20200319T101021
# Time matches
# True
# T32TQQ T33TUK
# 20200319T101021 20200319T101021
# Time matches
# True
# T32TQQ T33TUK
# 20200408T101021 20200408T101021
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20200617T101031 20200617T101031
# Time matches
# False
# T32TQQ T33TUK
# 20200816T101031 20200816T101031
# Time matches
# True
# T32TQQ T33TUK
# 20200816T101031 20200816T101031
# Time matches
# True
# T32TQQ T33TUK
# 20200816T101031 20200816T101031
# Time matches
# True
# T32TQQ T33TUK
# 20200816T101031 20200816T101031
# Time matches
# True
# T32TQQ T33TUK
# 20200816T101031 20200816T101031
# Time matches
# True
# T32TQQ T33TUK
# 20200816T101031 20200816T101031
# Time matches
# True
# T32TQQ T33TUK
# 20200826T101031 20200826T101031
# Time matches
# True
# T32TQQ T33TUK
# 20200826T101031 20200826T101031
# Time matches
# True
# T32TQQ T33TUK
# 20200905T101031 20200905T101031
# Time matches
# True
# T32TQQ T33TUK
# 20200905T101031 20200905T101031
# Time matches
# True
# T32TQQ T33TUK
# 20200905T101031 20200905T101031
# Time matches
# True
# T32TQQ T33TUK
# 20200905T101031 20200905T101031
# Time matches
# True
# T32TQQ T33TUK
# 20200905T101031 20200905T101031
# Time matches
# True
# T32TQQ T33TUK
# 20200905T101031 20200905T101031
# Time matches
# True
# T32TQQ T33TUK
# 20200905T101031 20200905T101031
# Time matches
# True
# T32TQQ T33TUK
# 20200905T101031 20200905T101031
# Time matches
# True
# T32TQQ T33TUK
# 20200915T101031 20200915T101031
# Time matches
# True
# T32TQQ T33TUK
# 20200915T101031 20200915T101031
# Time matches
# True
# T32TQQ T33TUK
# 20200915T101031 20200915T101031
# Time matches
# True
# T32TQQ T33TUK
# 20210324T101021 20210324T101021
# Time matches
# True
# T32TQQ T33TUK
# 20210324T101021 20210324T101021
# Time matches
# True
# T32TQQ T33TUK
# 20210324T101021 20210324T101021
# Time matches
# True
# T32TQQ T33TUK
# 20210324T101021 20210324T101021
# Time matches
# True
# T32TQQ T33TUK
# 20210324T101021 20210324T101021
# Time matches
# True
# T32TQQ T33TUK
# 20210324T101021 20210324T101021
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20210423T101021 20210423T101021
# Time matches
# False
# T32TQQ T33TUK
# 20210423T101021 20210423T101021
# Time matches
# True
# T32TQQ T33TUK
# 20210811T101031 20210811T101031
# Time matches
# True
# T32TQQ T33TUK
# 20150711T100006 20150711T100006
# Time matches
# True
# T32TQQ T33TUK
# 20150711T100006 20150711T100006
# Time matches
# True
# T32TQQ T33TUK
# 20150711T100006 20150711T100006
# Time matches
# True
# T32TQQ T33TUK
# 20150711T100006 20150711T100006
# Time matches
# True
# T32TQQ T33TUK
# 20150711T100006 20150711T100006
# Time matches
# True
# T32TQQ T33TUK
# 20150711T100006 20150711T100006
# Time matches
# True
# T32TQQ T33TUK
# 20150820T100016 20150820T100016
# Time matches
# True
# T32TQQ T33TUK
# 20150820T100016 20150820T100016
# Time matches
# True
# T32TQQ T33TUK
# 20150820T100016 20150820T100016
# Time matches
# True
# T32TQQ T33TUK
# 20150820T100016 20150820T100016
# Time matches
# True
# T32TQQ T33TUK
# 20150820T100016 20150820T100016
# Time matches
# True
# T32TQQ T33TUK
# 20150820T100016 20150820T100016
# Time matches
# True
# T32TQQ T33TUK
# 20150820T100016 20150820T100016
# Time matches
# True
# T32TQQ T33TUK
# 20150820T100016 20150820T100016
# Time matches
# True
# T32TQQ T33TUK
# 20150820T100016 20150820T100016
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20150830T100016 20150830T100016
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20150830T100016 20150830T100016
# Time matches
# False
# T32TQQ T33TUK
# 20150830T100016 20150830T100016
# Time matches
# True
# T32TQQ T33TUK
# 20150830T100016 20150830T100016
# Time matches
# True
# T32TQQ T33TUK
# 20150830T100016 20150830T100016
# Time matches
# True
# T32TQQ T33TUK
# 20150830T100016 20150830T100016
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20150830T100016 20150830T100016
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20150830T100016 20150830T100016
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20150830T100016 20150830T100016
# Time matches
# False
# T32TQQ T33TUK
# 20160506T100032 20160506T100032
# Time matches
# True
# T32TQQ T33TUK
# 20160506T100032 20160506T100032
# Time matches
# True
# T32TQQ T33TUK
# 20160506T100032 20160506T100032
# Time matches
# True
# T32TQQ T33TUK
# 20160506T100032 20160506T100032
# Time matches
# True
# T32TQQ T33TUK
# 20160506T100032 20160506T100032
# Time matches
# True
# T32TQQ T33TUK
# 20160506T100032 20160506T100032
# Time matches
# True
# T32TQQ T33TUK
# 20160605T100032 20160605T100032
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20160804T100032 20160804T100032
# Time matches
# False
# T32TQQ T33TUK
# 20160804T100032 20160804T100032
# Time matches
# True
# T32TQQ T33TUK
# 20160804T100032 20160804T100032
# Time matches
# True
# T32TQQ T33TUK
# 20160804T100032 20160804T100032
# Time matches
# True
# T32TQQ T33TUK
# 20160804T100032 20160804T100032
# Time matches
# True
# T32TQQ T33TUK
# 20160804T100032 20160804T100032
# Time matches
# True
# T32TQQ T33TUK
# 20160804T100032 20160804T100032
# Time matches
# True
# T32TQQ T33TUK
# 20160804T100032 20160804T100032
# Time matches
# True
# T32TQQ T33TUK
# 20160804T100032 20160804T100032
# Time matches
# True
# T32TQQ T33TUK
# 20160804T100032 20160804T100032
# Time matches
# True
# T32TQQ T33TUK
# 20160804T100032 20160804T100032
# Time matches
# True
# T32TQQ T33TUK
# 20160814T100032 20160814T100032
# Time matches
# True
# T32TQQ T33TUK
# 20160814T100032 20160814T100032
# Time matches
# True
# T32TQQ T33TUK
# 20160814T100032 20160814T100032
# Time matches
# True
# T32TQQ T33TUK
# 20160814T100032 20160814T100032
# Time matches
# True
# T32TQQ T33TUK
# 20160824T100032 20160824T100032
# Time matches
# True
# T32TQQ T33TUK
# 20160913T100022 20160913T100022
# Time matches
# True
# T32TQQ T33TUK
# 20160923T100022 20160923T100022
# Time matches
# True
# T32TQQ T33TUK
# 20170312T100021 20170312T100021
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20170312T100021 20170312T100021
# Time matches
# False
# T32TQQ T33TUK
# 20170312T100021 20170312T100021
# Time matches
# True
# T32TQQ T33TUK
# 20170312T100021 20170312T100021
# Time matches
# True
# T32TQQ T33TUK
# 20170312T100021 20170312T100021
# Time matches
# True
# T32TQQ T33TUK
# 20170312T100021 20170312T100021
# Time matches
# True
# T32TQQ T33TUK
# 20170312T100021 20170312T100021
# Time matches
# True
# T32TQQ T33TUK
# 20170312T100021 20170312T100021
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20170521T100031 20170521T100031
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20170521T100031 20170521T100031
# Time matches
# False
# T32TQQ T33TUK
# 20170521T100031 20170521T100031
# Time matches
# True
# T32TQQ T33TUK
# 20170521T100031 20170521T100031
# Time matches
# True
# T32TQQ T33TUK
# 20170521T100031 20170521T100031
# Time matches
# True
# T32TQQ T33TUK
# 20170521T100031 20170521T100031
# Time matches
# True
# T32TQQ T33TUK
# 20170521T100031 20170521T100031
# Time matches
# True
# T32TQQ T33TUK
# 20170521T100031 20170521T100031
# Time matches
# True
# T32TQQ T33TUK
# 20170521T100031 20170521T100031
# Time matches
# True
# T32TQQ T33TUK
# 20170521T100031 20170521T100031
# Time matches
# True
# T32TQQ T33TUK
# 20180426T100031 20180426T100031
# Time matches
# True
# T32TQQ T33TUK
# 20180516T100031 20180516T100031
# Time matches
# True
# T32TQQ T33TUK
# 20180516T100031 20180516T100031
# Time matches
# True
# T32TQQ T33TUK
# 20180516T100031 20180516T100031
# Time matches
# True
# T32TQQ T33TUK
# 20180516T100031 20180516T100031
# Time matches
# True
# T32TQQ T33TUK
# 20180516T100031 20180516T100031
# Time matches
# True
# T32TQQ T33TUK
# 20180516T100031 20180516T100031
# Time matches
# True
# T32TQQ T33TUK
# 20180526T100031 20180526T100031
# Time matches
# True
# T32TQQ T33TUK
# 20180526T100031 20180526T100031
# Time matches
# True
# T32TQQ T33TUK
# 20180526T100031 20180526T100031
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20180605T100031 20180605T100031
# Time matches
# False
# T32TQQ T33TUK
# 20180705T100031 20180705T100031
# Time matches
# True
# T32TQQ T33TUK
# 20180705T100031 20180705T100031
# Time matches
# True
# T32TQQ T33TUK
# 20180705T100031 20180705T100031
# Time matches
# True
# T32TQQ T33TUK
# 20180705T100031 20180705T100031
# Time matches
# True
# T32TQQ T33TUK
# 20180725T100031 20180725T100031
# Time matches
# True
# T32TQQ T33TUK
# 20180804T100031 20180804T100031
# Time matches
# True
# T32TQQ T33TUK
# 20180804T100031 20180804T100031
# Time matches
# True
# T32TQQ T33TUK
# 20180824T100031 20180824T100031
# Time matches
# True
# T32TQQ T33TUK
# 20180824T100031 20180824T100031
# Time matches
# True
# T32TQQ T33TUK
# 20180824T100031 20180824T100031
# Time matches
# True
# T32TQQ T33TUK
# 20180923T100021 20180923T100021
# Time matches
# True
# T32TQQ T33TUK
# 20180923T100021 20180923T100021
# Time matches
# True
# T32TQQ T33TUK
# 20181003T100021 20181003T100021
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20181013T100021 20181013T100021
# Time matches
# False
# T32TQQ T33TUK
# 20181013T100021 20181013T100021
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20190302T100021 20190302T100021
# Time matches
# False
# T32TQQ T33TUK
# 20190302T100021 20190302T100021
# Time matches
# True
# T32TQQ T33TUK
# 20190312T100021 20190312T100021
# Time matches
# True
# T32TQQ T33TUK
# 20190312T100021 20190312T100021
# Time matches
# True
# T32TQQ T33TUK
# 20190312T100021 20190312T100021
# Time matches
# True
# T32TQQ T33TUK
# 20190312T100021 20190312T100021
# Time matches
# True
# T32TQQ T33TUK
# 20190322T100031 20190322T100031
# Time matches
# True
# T32TQQ T33TUK
# 20190322T100031 20190322T100031
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20190322T100031 20190322T100031
# Time matches
# False
# T32TQQ T33TUK
# 20190501T100031 20190501T100031
# Time matches
# True
# T32TQQ T33TUK
# 20190531T100031 20190531T100031
# Time matches
# True
# T32TQQ T33TUK
# 20190531T100031 20190531T100031
# Time matches
# True
# T32TQQ T33TUK
# 20190531T100031 20190531T100031
# Time matches
# True
# T32TQQ T33TUK
# 20190531T100031 20190531T100031
# Time matches
# True
# T32TQQ T33TUK
# 20190720T100031 20190720T100031
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20190720T100031 20190720T100031
# Time matches
# False
# T32TQQ T33TUK
# 20190730T100031 20190730T100031
# Time matches
# True
# T32TQQ T33TUK
# 20190730T100031 20190730T100031
# Time matches
# True
# T32TQQ T33TUK
# 20190809T100031 20190809T100031
# Time matches
# True
# T32TQQ T33TUK
# 20190809T100031 20190809T100031
# Time matches
# True
# T32TQQ T33TUK
# 20190809T100031 20190809T100031
# Time matches
# True
# T32TQQ T33TUK
# 20190809T100031 20190809T100031
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20190819T100031 20190819T100031
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20190819T100031 20190819T100031
# Time matches
# False
# T32TQQ T33TUK
# 20190819T100031 20190819T100031
# Time matches
# True
# T32TQQ T33TUK
# 20190819T100031 20190819T100031
# Time matches
# True
# T32TQQ T33TUK
# 20190819T100031 20190819T100031
# Time matches
# True
# T32TQQ T33TUK
# 20190819T100031 20190819T100031
# Time matches
# True
# T32TQQ T33TUK
# 20190819T100031 20190819T100031
# Time matches
# True
# T32TQQ T33TUK
# 20191008T100031 20191008T100031
# Time matches
# True
# T32TQQ T33TUK
# 20200215T100111 20200215T100111
# Time matches
# True
# T32TQQ T33TUK
# 20200316T100021 20200316T100021
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20200525T100031 20200525T100031
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20200525T100031 20200525T100031
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20200525T100031 20200525T100031
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20200525T100031 20200525T100031
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20200525T100031 20200525T100031
# Time matches
# False
# T32TQQ T33TUK
# 20200525T100031 20200525T100031
# Time matches
# True
# T32TQQ T33TUK
# 20200525T100031 20200525T100031
# Time matches
# True
# T32TQQ T33TUK
# 20200525T100031 20200525T100031
# Time matches
# True
# T32TQQ T33TUK
# 20200902T100031 20200902T100031
# Time matches
# True
# T32TQQ T33TUK
# 20200902T100031 20200902T100031
# Time matches
# True
# T32TQQ T33TUK
# 20200902T100031 20200902T100031
# Time matches
# True
# T32TQQ T33TUK
# 20200912T100031 20200912T100031
# Time matches
# True
# T32TQQ T33TUK
# 20200912T100031 20200912T100031
# Time matches
# True
# T32TQQ T33TUK
# 20200912T100031 20200912T100031
# Time matches
# True
# T32TQQ T33TUK
# 20200912T100031 20200912T100031
# Time matches
# True
# T32TQQ T33TUK
# 20200912T100031 20200912T100031
# Time matches
# True
# T32TQQ T33TUK
# 20201111T100241 20201111T100241
# Time matches
# True
# T32TQQ T33TUK
# 20201111T100241 20201111T100241
# Time matches
# True
# T32TQQ T33TUK
# 20210301T100031 20210301T100031
# Time matches
# True
# T32TQQ T33TUK
# 20210301T100031 20210301T100031
# Time matches
# True
# T32TQQ T33TUK
# 20210301T100031 20210301T100031
# Time matches
# True
# T32TQQ T33TUK
# 20210301T100031 20210301T100031
# Time matches
# True
# T32TQQ T33TUK
# 20210331T100021 20210331T100021
# Time matches
# True
# T32TQQ T33TUK
# 20210331T100021 20210331T100021
# Time matches
# True
# T32TQQ T33TUK
# 20210331T100021 20210331T100021
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20210331T100021 20210331T100021
# Time matches
# False
# T32TQQ T33TUK
# 20210331T100021 20210331T100021
# Time matches
# True
# T32TQQ T33TUK
# 20210331T100021 20210331T100021
# Time matches
# True
# T32TQQ T33TUK
# 20210420T100021 20210420T100021
# Time matches
# True
# T32TQQ T33TUK
# 20210420T100021 20210420T100021
# Time matches
# True
# T32TQQ T33TUK
# 20210420T100021 20210420T100021
# Time matches
# True
# T32TQQ T33TUK
# 20210420T100021 20210420T100021
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20210520T100031 20210520T100031
# Time matches
# False
# T32TQQ T33TUK
# 20210520T100031 20210520T100031
# Time matches
# True
# T32TQQ T33TUK
# 20210520T100031 20210520T100031
# Time matches
# True
# T32TQQ T33TUK
# 20210520T100031 20210520T100031
# Time matches
# True
# T32TQQ T33TUK
# 20210520T100031 20210520T100031
# Time matches
# True
# T32TQQ T33TUK
# 20210520T100031 20210520T100031
# Time matches
# True
# T32TQQ T33TUK
# 20210520T100031 20210520T100031
# Time matches
# True
# T32TQQ T33TUK
# 20210520T100031 20210520T100031
# Time matches
# True
# T32TQQ T33TUK
# 20210520T100031 20210520T100031
# Time matches
# True
# T32TQQ T33TUK
# 20210520T100031 20210520T100031
# Time matches
# True
# T32TQQ T33TUK
# 20210520T100031 20210520T100031
# Time matches
# True
# T32TQQ T33TUL
# 20160827T101022 20160827T101022
# Time matches
# True
# T32TQQ T33TUL
# 20161006T101022 20161006T101022
# Time matches
# True
# T32TQQ T33TUL
# 20170325T101021 20170325T101021
# Time matches
# True
# T32TQQ T33TUL
# 20170325T101021 20170325T101021
# Time matches
# True
# T33TUK T33TUL
# 20170404T101021 20170404T101021
# Time matches
# True
# T33TUK T33TUL
# 20170404T101021 20170404T101021
# Time matches
# True
# T32TQQ T33TUL
# 20170921T101021 20170921T101021
# Time matches
# True
# T32TQQ T33TUL
# 20170921T101021 20170921T101021
# Time matches
# True
# T32TQQ T33TUL
# 20170921T101021 20170921T101021
# Time matches
# True
# T32TQR T33TUL
# 20180906T101021 20180906T101021
# Time matches
# True
# T32TQR T33TUL
# 20180906T101021 20180906T101021
# Time matches
# True
# T32TQR T33TUL
# 20180906T101021 20180906T101021
# Time matches
# True
# T32TQR T33TUL
# 20180906T101021 20180906T101021
# Time matches
# True
# T32TQR T33TUL
# 20190213T101131 20190213T101131
# Time matches
# True
# T32TQR T33TUL
# 20190213T101131 20190213T101131
# Time matches
# True
# T32TQQ T33TUL
# 20190213T101131 20190213T101131
# Time matches
# True
# T32TQQ T33TUL
# 20190213T101131 20190213T101131
# Time matches
# True
# T32TQQ T33TUL
# 20190213T101131 20190213T101131
# Time matches
# True
# T32TQQ T33TUL
# 20190213T101131 20190213T101131
# Time matches
# True
# T32TQQ T33TUL
# 20190723T101031 20190723T101031
# Time matches
# True
# T32TQQ T33TUL
# 20190723T101031 20190723T101031
# Time matches
# True
# T32TQQ T33TUL
# 20200319T101021 20200319T101021
# Time matches
# True
# T33TUK T33TUL
# 20200617T101031 20200617T101031
# Time matches
# True
# T32TQR T33TUL
# 20200905T101031 20200905T101031
# Time matches
# True
# T32TQQ T33TUL
# 20200905T101031 20200905T101031
# Time matches
# True
# T32TQQ T33TUL
# 20210324T101021 20210324T101021
# Time matches
# True
# T33TUK T33TUL
# 20210423T101021 20210423T101021
# Time matches
# True
# T33TUK T33TUL
# 20210423T101021 20210423T101021
# Time matches
# True
# T33TUK T33TUL
# 20210423T101021 20210423T101021
# Time matches
# True
# T33TUK T33TUL
# 20150711T100006 20150711T100006
# Time matches
# True
# T32TQR T33TUL
# 20150830T100016 20150830T100016
# Time matches
# True
# T33TUK T33TUL
# 20150830T100016 20150830T100016
# Time matches
# True
# T32TQQ T33TUL
# 20160804T100032 20160804T100032
# Time matches
# True
# T32TQR T33TUL
# 20160824T100032 20160824T100032
# Time matches
# True
# T32TQR T33TUL
# 20160824T100032 20160824T100032
# Time matches
# True
# T32TQR T33TUL
# 20160923T100022 20160923T100022
# Time matches
# True
# T32TQQ T33TUL
# 20170220T100031 20170220T100031
# Time matches
# True
# T32TQR T33TUL
# 20170312T100021 20170312T100021
# Time matches
# True
# T32TQR T33TUL
# 20170312T100021 20170312T100021
# Time matches
# True
# T33TUK T33TUL
# 20170312T100021 20170312T100021
# Time matches
# True
# T32TQQ T33TUL
# 20170521T100031 20170521T100031
# Time matches
# True
# T32TQR T33TUL
# 20171008T100031 20171008T100031
# Time matches
# True
# T32TQQ T33TUL
# 20171008T100031 20171008T100031
# Time matches
# True
# T32TQQ T33TUL
# 20180327T100031 20180327T100031
# Time matches
# True
# T32TQQ T33TUL
# 20180526T100031 20180526T100031
# Time matches
# True
# T32TQR T33TUL
# 20180605T100031 20180605T100031
# Time matches
# True
# T32TQR T33TUL
# 20180705T100031 20180705T100031
# Time matches
# True
# T32TQR T33TUL
# 20180705T100031 20180705T100031
# Time matches
# True
# T32TQR T33TUL
# 20180705T100031 20180705T100031
# Time matches
# True
# T33TUK T33TUL
# 20180705T100031 20180705T100031
# Time matches
# True
# T33TUK T33TUL
# 20180705T100031 20180705T100031
# Time matches
# True
# T33TUK T33TUL
# 20180705T100031 20180705T100031
# Time matches
# True
# T32TQQ T33TUL
# 20180705T100031 20180705T100031
# Time matches
# True
# T32TQQ T33TUL
# 20180705T100031 20180705T100031
# Time matches
# True
# T32TQQ T33TUL
# 20180705T100031 20180705T100031
# Time matches
# True
# T32TQQ T33TUL
# 20180705T100031 20180705T100031
# Time matches
# True
# T32TQR T33TUL
# 20180923T100021 20180923T100021
# Time matches
# True
# T33TUK T33TUL
# 20180923T100021 20180923T100021
# Time matches
# True
# T33TUK T33TUL
# 20180923T100021 20180923T100021
# Time matches
# True
# T32TQQ T33TUL
# 20180923T100021 20180923T100021
# Time matches
# True
# T32TQQ T33TUL
# 20181003T100021 20181003T100021
# Time matches
# True
# T32TQQ T33TUL
# 20190501T100031 20190501T100031
# Time matches
# True
# T32TQR T33TUL
# 20190531T100031 20190531T100031
# Time matches
# True
# T32TQR T33TUL
# 20190531T100031 20190531T100031
# Time matches
# True
# T32TQQ T33TUL
# 20190531T100031 20190531T100031
# Time matches
# True
# T32TQQ T33TUL
# 20190531T100031 20190531T100031
# Time matches
# True
# T32TQR T33TUL
# 20190819T100031 20190819T100031
# Time matches
# True
# T33TUK T33TUL
# 20190819T100031 20190819T100031
# ...
# Tile ID matches
# 20180610T100029 20180610T100029
# Time matches
# False
# T33TUK T32TQQ
# 20180620T100029 20180620T100029
# Time matches
# True
# T32TQQ T32TQQ
# Tile ID matches
# 20180630T100029 20180630T100029
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180630T100029 20180630T100029
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180630T100029 20180630T100029
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180630T100029 20180630T100029
# Time matches
# False
# T33TUK T32TQQ
# 20180730T100029 20180730T100029
# Time matches
# True
# T32TQQ T32TQQ
# Tile ID matches
# 20180908T100019 20180908T100019
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180918T100019 20180918T100019
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180928T100019 20180928T100019
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180928T100019 20180928T100019
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20180928T100019 20180928T100019
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190225T100029 20190225T100029
# Time matches
# False
# T33TUK T32TQQ
# 20190416T100029 20190416T100029
# Time matches
# True
# T33TUK T32TQQ
# 20190516T100039 20190516T100039
# Time matches
# True
# T32TQQ T32TQQ
# Tile ID matches
# 20190516T100039 20190516T100039
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190516T100039 20190516T100039
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190625T100039 20190625T100039
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190705T100039 20190705T100039
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190705T100039 20190705T100039
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190705T100039 20190705T100039
# Time matches
# False
# T33TUK T32TQQ
# 20190913T100029 20190913T100029
# Time matches
# True
# T32TQQ T32TQQ
# Tile ID matches
# 20190913T100029 20190913T100029
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20190913T100029 20190913T100029
# Time matches
# False
# T33TUK T32TQQ
# 20200220T100029 20200220T100029
# Time matches
# True
# T32TQQ T32TQQ
# Tile ID matches
# 20200220T100029 20200220T100029
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200220T100029 20200220T100029
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200220T100029 20200220T100029
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200311T100029 20200311T100029
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200311T100029 20200311T100029
# Time matches
# False
# T33TUK T32TQQ
# 20200410T100029 20200410T100029
# Time matches
# True
# T32TQQ T32TQQ
# Tile ID matches
# 20200619T100029 20200619T100029
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200619T100029 20200619T100029
# Time matches
# False
# T33TUK T32TQQ
# 20200709T100029 20200709T100029
# Time matches
# True
# T32TQQ T32TQQ
# Tile ID matches
# 20200709T100029 20200709T100029
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200709T100029 20200709T100029
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200719T100029 20200719T100029
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200907T100029 20200907T100029
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20200907T100029 20200907T100029
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210425T100019 20210425T100019
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210425T100019 20210425T100019
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210425T100019 20210425T100019
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210425T100019 20210425T100019
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210425T100019 20210425T100019
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210525T100029 20210525T100029
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210525T100029 20210525T100029
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210604T100029 20210604T100029
# Time matches
# False
# T32TQQ T32TQQ
# Tile ID matches
# 20210604T100029 20210604T100029
# Time matches
# False
# T32TQQ T32TQR
# 20171016T101009 20171016T101009
# Time matches
# True
# T32TQQ T32TQR
# 20181031T101139 20181031T101139
# Time matches
# True
# T32TQQ T32TQR
# 20190208T101159 20190208T101159
# Time matches
# True
# T33TUK T32TQR
# 20190916T101029 20190916T101029
# Time matches
# True
# T32TQQ T32TQR
# 20190916T101029 20190916T101029
# Time matches
# True
# T32TQQ T32TQR
# 20190916T101029 20190916T101029
# Time matches
# True
# T32TQR T32TQR
# Tile ID matches
# 20170705T100029 20170705T100029
# Time matches
# False
# T32TQR T32TQR
# Tile ID matches
# 20170705T100029 20170705T100029
# Time matches
# False
# T32TQR T32TQR
# Tile ID matches
# 20170705T100029 20170705T100029
# Time matches
# False
# T33TUK T32TQR
# 20170824T100019 20170824T100019
# Time matches
# True
# T32TQQ T32TQR
# 20170824T100019 20170824T100019
# Time matches
# True
# T32TQR T32TQR
# Tile ID matches
# 20180610T100029 20180610T100029
# Time matches
# False
# T32TQR T32TQR
# Tile ID matches
# 20180730T100029 20180730T100029
# Time matches
# False
# T32TQQ T32TQR
# 20180730T100029 20180730T100029
# Time matches
# True
# T32TQR T32TQR
# Tile ID matches
# 20180908T100019 20180908T100019
# Time matches
# False
# T33TUK T32TQR
# 20180908T100019 20180908T100019
# Time matches
# True
# T32TQQ T32TQR
# 20180908T100019 20180908T100019
# Time matches
# True
# T32TQQ T32TQR
# 20180928T100019 20180928T100019
# Time matches
# True
# T32TQR T32TQR
# Tile ID matches
# 20190406T100029 20190406T100029
# Time matches
# False
# T32TQQ T32TQR
# 20190416T100029 20190416T100029
# Time matches
# True
# T32TQQ T32TQR
# 20190705T100039 20190705T100039
# Time matches
# True
# T32TQQ T32TQR
# 20200220T100029 20200220T100029
# Time matches
# True
# T32TQQ T32TQR
# 20200220T100029 20200220T100029
# Time matches
# True
# T32TQQ T32TQR
# 20200430T100019 20200430T100019
# Time matches
# True
# T32TQR T32TQR
# Tile ID matches
# 20200709T100029 20200709T100029
# Time matches
# False
# T33TUK T32TQR
# 20200709T100029 20200709T100029
# Time matches
# True
# T32TQQ T32TQR
# 20200709T100029 20200709T100029
# Time matches
# True
# T32TQQ T32TQR
# 20200828T100029 20200828T100029
# Time matches
# True
# T32TQR T32TQR
# Tile ID matches
# 20210425T100019 20210425T100019
# Time matches
# False
# T32TQR T32TQR
# Tile ID matches
# 20210425T100019 20210425T100019
# Time matches
# False
# T32TQQ T32TQR
# 20210425T100019 20210425T100019
# Time matches
# True
# T32TQR T32TQR
# Tile ID matches
# 20210604T100029 20210604T100029
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20190331T094039 20190331T094039
# Time matches
# False
# T33SXC T33SXC
# Tile ID matches
# 20200812T094039 20200812T094039
# Time matches
# False
# T32TQQ T33TUK
# 20170718T101029 20170718T101029
# Time matches
# True
# T32TQQ T33TUK
# 20170718T101029 20170718T101029
# Time matches
# True
# T32TQQ T33TUK
# 20170718T101029 20170718T101029
# Time matches
# True
# T32TQQ T33TUK
# 20170718T101029 20170718T101029
# Time matches
# True
# T32TQQ T33TUK
# 20170718T101029 20170718T101029
# Time matches
# True
# T32TQQ T33TUK
# 20170926T101009 20170926T101009
# Time matches
# True
# T32TQQ T33TUK
# 20170926T101009 20170926T101009
# Time matches
# True
# T32TQQ T33TUK
# 20170926T101009 20170926T101009
# Time matches
# True
# T32TQQ T33TUK
# 20170926T101009 20170926T101009
# Time matches
# True
# T32TQQ T33TUK
# 20170926T101009 20170926T101009
# Time matches
# True
# T32TQQ T33TUK
# 20170926T101009 20170926T101009
# Time matches
# True
# T32TQQ T33TUK
# 20180822T101019 20180822T101019
# Time matches
# True
# T32TQQ T33TUK
# 20180921T101019 20180921T101019
# Time matches
# True
# T32TQQ T33TUK
# 20180921T101019 20180921T101019
# Time matches
# True
# T32TQQ T33TUK
# 20181011T101019 20181011T101019
# Time matches
# True
# T32TQQ T33TUK
# 20181021T101039 20181021T101039
# Time matches
# True
# T32TQQ T33TUK
# 20181021T101039 20181021T101039
# Time matches
# True
# T32TQQ T33TUK
# 20181031T101139 20181031T101139
# Time matches
# True
# T32TQQ T33TUK
# 20181031T101139 20181031T101139
# Time matches
# True
# T32TQQ T33TUK
# 20181031T101139 20181031T101139
# Time matches
# True
# T32TQQ T33TUK
# 20190208T101159 20190208T101159
# Time matches
# True
# T32TQQ T33TUK
# 20190208T101159 20190208T101159
# Time matches
# True
# T32TQQ T33TUK
# 20190228T101029 20190228T101029
# Time matches
# True
# T32TQQ T33TUK
# 20190228T101029 20190228T101029
# Time matches
# True
# T32TQQ T33TUK
# 20190228T101029 20190228T101029
# Time matches
# True
# T32TQQ T33TUK
# 20190330T101029 20190330T101029
# Time matches
# True
# T32TQQ T33TUK
# 20190916T101029 20190916T101029
# Time matches
# True
# T32TQQ T33TUK
# 20190916T101029 20190916T101029
# Time matches
# True
# T32TQQ T33TUK
# 20190916T101029 20190916T101029
# Time matches
# True
# T32TQQ T33TUK
# 20200612T100559 20200612T100559
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20200622T100559 20200622T100559
# Time matches
# False
# T32TQQ T33TUK
# 20200622T100559 20200622T100559
# Time matches
# True
# T32TQQ T33TUK
# 20200622T100559 20200622T100559
# Time matches
# True
# T32TQQ T33TUK
# 20200622T100559 20200622T100559
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20200811T100559 20200811T100559
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20200821T100559 20200821T100559
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20200910T100559 20200910T100559
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20210329T100609 20210329T100609
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20210329T100609 20210329T100609
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20210329T100609 20210329T100609
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20210329T100609 20210329T100609
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20210329T100609 20210329T100609
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20210329T100609 20210329T100609
# Time matches
# False
# T32TQQ T33TUK
# 20210408T100549 20210408T100549
# Time matches
# True
# T32TQQ T33TUK
# 20210408T100549 20210408T100549
# Time matches
# True
# T32TQQ T33TUK
# 20210408T100549 20210408T100549
# Time matches
# True
# T32TQQ T33TUK
# 20210408T100549 20210408T100549
# Time matches
# True
# T32TQQ T33TUK
# 20210408T100549 20210408T100549
# Time matches
# True
# T32TQQ T33TUK
# 20210518T100559 20210518T100559
# Time matches
# True
# T32TQQ T33TUK
# 20170824T100019 20170824T100019
# Time matches
# True
# T32TQQ T33TUK
# 20180421T100029 20180421T100029
# Time matches
# True
# T32TQQ T33TUK
# 20180421T100029 20180421T100029
# Time matches
# True
# T32TQQ T33TUK
# 20180421T100029 20180421T100029
# Time matches
# True
# T32TQQ T33TUK
# 20180511T100029 20180511T100029
# Time matches
# True
# T32TQQ T33TUK
# 20180610T100029 20180610T100029
# Time matches
# True
# T32TQQ T33TUK
# 20180610T100029 20180610T100029
# Time matches
# True
# T32TQQ T33TUK
# 20180620T100029 20180620T100029
# Time matches
# True
# T32TQQ T33TUK
# 20180630T100029 20180630T100029
# Time matches
# True
# T32TQQ T33TUK
# 20180630T100029 20180630T100029
# Time matches
# True
# T32TQQ T33TUK
# 20180630T100029 20180630T100029
# Time matches
# True
# T32TQQ T33TUK
# 20180630T100029 20180630T100029
# Time matches
# True
# T32TQQ T33TUK
# 20180630T100029 20180630T100029
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20180630T100029 20180630T100029
# Time matches
# False
# T32TQQ T33TUK
# 20180908T100019 20180908T100019
# Time matches
# True
# T32TQQ T33TUK
# 20180908T100019 20180908T100019
# Time matches
# True
# T32TQQ T33TUK
# 20180928T100019 20180928T100019
# Time matches
# True
# T32TQQ T33TUK
# 20180928T100019 20180928T100019
# Time matches
# True
# T32TQQ T33TUK
# 20190225T100029 20190225T100029
# Time matches
# True
# T32TQQ T33TUK
# 20190225T100029 20190225T100029
# Time matches
# True
# T32TQQ T33TUK
# 20190225T100029 20190225T100029
# Time matches
# True
# T32TQQ T33TUK
# 20190416T100029 20190416T100029
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20190416T100029 20190416T100029
# Time matches
# False
# T32TQQ T33TUK
# 20190516T100039 20190516T100039
# Time matches
# True
# T32TQQ T33TUK
# 20190516T100039 20190516T100039
# Time matches
# True
# T32TQQ T33TUK
# 20190516T100039 20190516T100039
# Time matches
# True
# T32TQQ T33TUK
# 20190625T100039 20190625T100039
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20190705T100039 20190705T100039
# Time matches
# False
# T32TQQ T33TUK
# 20190705T100039 20190705T100039
# Time matches
# True
# T32TQQ T33TUK
# 20190705T100039 20190705T100039
# Time matches
# True
# T32TQQ T33TUK
# 20190913T100029 20190913T100029
# Time matches
# True
# T32TQQ T33TUK
# 20190913T100029 20190913T100029
# Time matches
# True
# T32TQQ T33TUK
# 20200220T100029 20200220T100029
# Time matches
# True
# T32TQQ T33TUK
# 20200220T100029 20200220T100029
# Time matches
# True
# T32TQQ T33TUK
# 20200220T100029 20200220T100029
# Time matches
# True
# T32TQQ T33TUK
# 20200220T100029 20200220T100029
# Time matches
# True
# T32TQQ T33TUK
# 20200311T100029 20200311T100029
# Time matches
# True
# T32TQQ T33TUK
# 20200410T100029 20200410T100029
# Time matches
# True
# T32TQQ T33TUK
# 20200410T100029 20200410T100029
# Time matches
# True
# T32TQQ T33TUK
# 20200619T100029 20200619T100029
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20200709T100029 20200709T100029
# Time matches
# False
# T32TQQ T33TUK
# 20200709T100029 20200709T100029
# Time matches
# True
# T32TQQ T33TUK
# 20200709T100029 20200709T100029
# Time matches
# True
# T32TQQ T33TUK
# 20200709T100029 20200709T100029
# Time matches
# True
# T32TQQ T33TUK
# 20200719T100029 20200719T100029
# Time matches
# True
# T32TQQ T33TUK
# 20200828T100029 20200828T100029
# Time matches
# True
# T32TQQ T33TUK
# 20200907T100029 20200907T100029
# Time matches
# True
# T32TQQ T33TUK
# 20200917T100029 20200917T100029
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20201106T100219 20201106T100219
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20210425T100019 20210425T100019
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20210425T100019 20210425T100019
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20210425T100019 20210425T100019
# Time matches
# False
# T32TQQ T33TUK
# 20210425T100019 20210425T100019
# Time matches
# True
# T33TUK T33TUK
# Tile ID matches
# 20210425T100019 20210425T100019
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20210425T100019 20210425T100019
# Time matches
# False
# T33TUK T33TUK
# Tile ID matches
# 20210425T100019 20210425T100019
# Time matches
# False
# T32TQQ T33TUK
# 20210525T100029 20210525T100029
# Time matches
# True
# T32TQQ T33TUK
# 20210604T100029 20210604T100029
# Time matches
# True
# T33TUK T33TUL
# 20170718T101029 20170718T101029
# Time matches
# True
# T32TQQ T33TUL
# 20170718T101029 20170718T101029
# Time matches
# True
# T32TQR T33TUL
# 20180921T101019 20180921T101019
# Time matches
# True
# T32TQR T33TUL
# 20180921T101019 20180921T101019
# Time matches
# True
# T32TQR T33TUL
# 20181031T101139 20181031T101139
# Time matches
# True
# T32TQQ T33TUL
# 20181031T101139 20181031T101139
# Time matches
# True
# T32TQR T33TUL
# 20190208T101159 20190208T101159
# Time matches
# True
# T32TQR T33TUL
# 20190228T101029 20190228T101029
# Time matches
# True
# T33TUK T33TUL
# 20190916T101029 20190916T101029
# Time matches
# True
# T32TQQ T33TUL
# 20190916T101029 20190916T101029
# Time matches
# True
# T33TUK T33TUL
# 20200622T100559 20200622T100559
# Time matches
# True
# T32TQQ T33TUL
# 20200622T100559 20200622T100559
# Time matches
# True
# T33TUK T33TUL
# 20200811T100559 20200811T100559
# Time matches
# True
# T33TUK T33TUL
# 20200811T100559 20200811T100559
# Time matches
# True
# T32TQR T33TUL
# 20200910T100559 20200910T100559
# Time matches
# True
# T32TQR T33TUL
# 20201109T101239 20201109T101239
# Time matches
# True
# T32TQR T33TUL
# 20170705T100029 20170705T100029
# Time matches
# True
# T33TUK T33TUL
# 20170705T100029 20170705T100029
# Time matches
# True
# T32TQR T33TUL
# 20170824T100019 20170824T100019
# Time matches
# True
# T33TUK T33TUL
# 20170824T100019 20170824T100019
# Time matches
# True
# T32TQR T33TUL
# 20180610T100029 20180610T100029
# Time matches
# True
# T32TQQ T33TUL
# 20180630T100029 20180630T100029
# Time matches
# True
# T32TQQ T33TUL
# 20180630T100029 20180630T100029
# Time matches
# True
# T32TQR T33TUL
# 20180720T100029 20180720T100029
# Time matches
# True
# T33TUL T33TUL
# Tile ID matches
# 20180720T100029 20180720T100029
# Time matches
# False
# T32TQQ T33TUL
# 20180908T100019 20180908T100019
# Time matches
# True
# T32TQR T33TUL
# 20181117T100259 20181117T100259
# Time matches
# True
# T33TUK T33TUL
# 20190416T100029 20190416T100029
# Time matches
# True
# T32TQQ T33TUL
# 20190913T100029 20190913T100029
# Time matches
# True
# T32TQQ T33TUL
# 20200220T100029 20200220T100029
# Time matches
# True
# T33TUK T33TUL
# 20200619T100029 20200619T100029
# Time matches
# True
# T32TQR T33TUL
# 20200719T100029 20200719T100029
# Time matches
# True
# T32TQQ T33TUL
# 20200808T100029 20200808T100029
# Time matches
# True
# T32TQQ T33TUL
# 20200828T100029 20200828T100029
# Time matches
# True
# T33TUL T33TUL
# Tile ID matches
# 20210425T100019 20210425T100019
# Time matches
# False
# T32TQR T33TUL
# 20210425T100019 20210425T100019
# Time matches
# True
# T32TQR T33TUL
# 20210425T100019 20210425T100019
# Time matches
# True
# T33TUK T33TUL
# 20210425T100019 20210425T100019
# Time matches
# True
# T33TUK T33TUL
# 20210425T100019 20210425T100019
# Time matches
# True
# T33TUK T33TUL
# 20210425T100019 20210425T100019
# Time matches
# True
# T32TQR T33TUL
# 20210604T100029 20210604T100029
# Time matches
# True

# %%
df['mis_match'].value_counts()
# Out:
# mis_match
# True     567
# False    399
# Name: count, dtype: int64

# %%
df['updated_product_id'].unique()
# Out:
# array(['S2A_MSIL1C_20170723T101031_N0500_R022_T32TMN_20231008T072550.SAFE',
#        'S2A_MSIL1C_20170921T101021_N0500_R022_T32TMN_20231014T085005.SAFE',
#        'S2A_MSIL1C_20180509T101031_N0500_R022_T32TMN_20230829T201517.SAFE',
#        'S2A_MSIL1C_20180323T102021_N0500_R065_T32TMN_20230904T190420.SAFE',
#        'S2A_MSIL1C_20200521T102031_N0500_R065_T32TMN_20230503T140151.SAFE',
#        'S2A_MSIL1C_20201018T102041_N0500_R065_T32TMN_20230414T050856.SAFE',
#        'S2A_MSIL1C_20170517T102031_N0500_R065_T32TMP_20231114T020912.SAFE',
#        'S2A_MSIL1C_20170527T102031_N0500_R065_T32TMP_20231111T145716.SAFE',
#        'S2A_MSIL1C_20170616T102021_N0500_R065_T32TMP_20231012T144506.SAFE',
#        'S2A_MSIL1C_20180422T102031_N0500_R065_T32TMP_20230915T072546.SAFE',
#        'S2A_MSIL1C_20200521T102031_N0500_R065_T32TMP_20230503T140151.SAFE',
#        'S2A_MSIL1C_20201018T102041_N0500_R065_T32TMP_20230414T050856.SAFE',
#        'S2A_MSIL1C_20170424T101031_N0500_R022_T32TMN_20231114T114644.SAFE',
#        'S2A_MSIL1C_20170424T101031_N0500_R022_T32TNN_20231114T114644.SAFE',
#        'S2A_MSIL1C_20170504T101031_N0500_R022_T32TNN_20231113T112005.SAFE',
#        'S2A_MSIL1C_20210317T102021_N0500_R065_T32TMN_20230514T164337.SAFE',
#        'S2A_MSIL1C_20200521T102031_N0500_R065_T32TNP_20230503T140151.SAFE',
#        'S2A_MSIL1C_20160429T101032_N0500_R022_T32TQQ_20231024T163712.SAFE',
#        'S2A_MSIL1C_20160618T101032_N0500_R022_T32TQQ_20231027T024351.SAFE',
#        'S2A_MSIL1C_20160827T101022_N0500_R022_T32TQQ_20231021T110119.SAFE',
#        'S2A_MSIL1C_20160926T101022_N0500_R022_T32TQQ_20231023T054506.SAFE',
#        'S2A_MSIL1C_20161006T101022_N0500_R022_T32TQQ_20231025T195648.SAFE',
#        'S2A_MSIL1C_20170325T101021_N0500_R022_T32TQQ_20231024T213459.SAFE',
#        'S2A_MSIL1C_20170921T101021_N0500_R022_T33TUK_20231014T085005.SAFE',
#        'S2A_MSIL1C_20170921T101021_N0500_R022_T32TQQ_20231014T085005.SAFE',
#        'S2A_MSIL1C_20180906T101021_N0500_R022_T32TQQ_20230712T073442.SAFE',
#        'S2A_MSIL1C_20180916T101021_N0500_R022_T32TQQ_20230731T155221.SAFE',
#        'S2A_MSIL1C_20190213T101131_N0500_R022_T33TUK_20221128T153324.SAFE',
#        'S2A_MSIL1C_20190213T101131_N0500_R022_T32TQQ_20221128T153324.SAFE',
#        'S2A_MSIL1C_20190315T101021_N0500_R022_T32TQQ_20221116T052920.SAFE',
#        'S2A_MSIL1C_20190325T101021_N0500_R022_T32TQQ_20221117T131900.SAFE',
#        'S2A_MSIL1C_20190723T101031_N0500_R022_T32TQQ_20230718T015529.SAFE',
#        'S2A_MSIL1C_20191011T101031_N0500_R022_T32TQQ_20230708T021625.SAFE',
#        'S2A_MSIL1C_20200319T101021_N0500_R022_T32TQQ_20230628T195927.SAFE',
#        'S2A_MSIL1C_20200816T101031_N0500_R022_T32TQQ_20230422T024451.SAFE',
#        'S2A_MSIL1C_20200826T101031_N0500_R022_T32TQQ_20230412T174525.SAFE',
#        'S2A_MSIL1C_20200905T101031_N0500_R022_T33TUK_20230418T234442.SAFE',
#        'S2A_MSIL1C_20200905T101031_N0500_R022_T32TQQ_20230418T234442.SAFE',
#        'S2A_MSIL1C_20200915T101031_N0500_R022_T32TQQ_20230415T174104.SAFE',
#        'S2A_MSIL1C_20210324T101021_N0500_R022_T33TUK_20230607T160409.SAFE',
#        'S2A_MSIL1C_20210324T101021_N0500_R022_T32TQQ_20230607T160409.SAFE',
#        'S2A_MSIL1C_20150711T100006_N0500_R122_T32TQQ_20231011T083658.SAFE',
#        'S2A_MSIL1C_20150820T100016_N0500_R122_T32TQQ_20231009T102246.SAFE',
#        'S2A_MSIL1C_20150830T100016_N0500_R122_T32TQQ_20231016T110421.SAFE',
#        'S2A_MSIL1C_20160506T100032_N0500_R122_T32TQQ_20231027T050524.SAFE',
#        'S2A_MSIL1C_20160605T100032_N0500_R122_T32TQQ_20231027T040825.SAFE',
#        'S2A_MSIL1C_20160804T100032_N0500_R122_T32TQQ_20231026T150644.SAFE',
#        'S2A_MSIL1C_20160814T100032_N0500_R122_T32TQQ_20231027T023353.SAFE',
#        'S2A_MSIL1C_20160824T100032_N0500_R122_T32TQQ_20231026T160517.SAFE',
#        'S2A_MSIL1C_20160913T100022_N0500_R122_T32TQQ_20231028T112643.SAFE',
#        'S2A_MSIL1C_20170421T100031_N0500_R122_T32TQQ_20231110T145456.SAFE',
#        'S2A_MSIL1C_20170521T100031_N0500_R122_T32TQQ_20231113T203902.SAFE',
#        'S2A_MSIL1C_20180426T100031_N0500_R122_T32TQQ_20230830T165103.SAFE',
#        'S2A_MSIL1C_20180516T100031_N0500_R122_T33TUK_20230903T095806.SAFE',
#        'S2A_MSIL1C_20180516T100031_N0500_R122_T32TQQ_20230903T095806.SAFE',
#        'S2A_MSIL1C_20180526T100031_N0500_R122_T32TQQ_20230902T114451.SAFE',
#        'S2A_MSIL1C_20180705T100031_N0500_R122_T33TUK_20230805T194837.SAFE',
#        'S2A_MSIL1C_20180705T100031_N0500_R122_T32TQQ_20230805T194837.SAFE',
#        'S2A_MSIL1C_20180804T100031_N0500_R122_T32TQQ_20230811T125853.SAFE',
#        'S2A_MSIL1C_20180824T100031_N0500_R122_T32TQQ_20230816T221132.SAFE',
#        'S2A_MSIL1C_20180923T100021_N0500_R122_T32TQQ_20230819T205944.SAFE',
#        'S2A_MSIL1C_20181003T100021_N0500_R122_T32TQQ_20230626T033452.SAFE',
#        'S2A_MSIL1C_20190302T100021_N0500_R122_T32TQQ_20221112T030944.SAFE',
#        'S2A_MSIL1C_20190312T100021_N0500_R122_T32TQQ_20221115T172347.SAFE',
#        'S2A_MSIL1C_20190501T100031_N0500_R122_T32TQQ_20221219T071444.SAFE',
#        'S2A_MSIL1C_20190531T100031_N0500_R122_T32TQQ_20221213T082018.SAFE',
#        'S2A_MSIL1C_20190620T100031_N0500_R122_T32TQQ_20230722T153818.SAFE',
#        'S2A_MSIL1C_20190730T100031_N0500_R122_T32TQQ_20230710T202111.SAFE',
#        'S2A_MSIL1C_20190809T100031_N0500_R122_T32TQQ_20230515T073846.SAFE',
#        'S2A_MSIL1C_20190819T100031_N0500_R122_T32TQQ_20230719T223350.SAFE',
#        'S2A_MSIL1C_20191008T100031_N0500_R122_T33TUK_20230613T122804.SAFE',
#        'S2A_MSIL1C_20200316T100021_N0500_R122_T33TUK_20230407T214446.SAFE',
#        'S2A_MSIL1C_20200316T100021_N0500_R122_T32TQQ_20230407T214446.SAFE',
#        'S2A_MSIL1C_20200525T100031_N0500_R122_T32TQQ_20230509T083609.SAFE',
#        'S2A_MSIL1C_20200902T100031_N0500_R122_T32TQQ_20230311T202103.SAFE',
#        'S2A_MSIL1C_20200912T100031_N0500_R122_T33TUK_20230311T041435.SAFE',
#        'S2A_MSIL1C_20200912T100031_N0500_R122_T32TQQ_20230311T041435.SAFE',
#        'S2A_MSIL1C_20201111T100241_N0500_R122_T32TQQ_20230302T103445.SAFE',
#        'S2A_MSIL1C_20210301T100031_N0500_R122_T33TUK_20230524T164147.SAFE',
#        'S2A_MSIL1C_20210301T100031_N0500_R122_T32TQQ_20230524T164147.SAFE',
#        'S2A_MSIL1C_20210420T100021_N0500_R122_T32TQQ_20230522T132445.SAFE',
#        'S2A_MSIL1C_20210520T100031_N0500_R122_T33TUK_20230329T185738.SAFE',
#        'S2A_MSIL1C_20210520T100031_N0500_R122_T32TQQ_20230329T185738.SAFE',
#        'S2A_MSIL1C_20150813T101026_N0500_R022_T32TQQ_20231009T135741.SAFE',
#        'S2A_MSIL1C_20150912T101403_N0500_R022_T32TQQ_20231009T083635.SAFE',
#        'S2A_MSIL1C_20170921T101021_N0500_R022_T32TQR_20231014T085005.SAFE',
#        'S2A_MSIL1C_20180906T101021_N0500_R022_T32TQR_20230712T073442.SAFE',
#        'S2A_MSIL1C_20190213T101131_N0500_R022_T32TQR_20221128T153324.SAFE',
#        'S2A_MSIL1C_20200617T101031_N0500_R022_T33TUK_20230429T180325.SAFE',
#        'S2A_MSIL1C_20200905T101031_N0500_R022_T32TQR_20230418T234442.SAFE',
#        'S2A_MSIL1C_20150830T100016_N0500_R122_T32TQR_20231016T110421.SAFE',
#        'S2A_MSIL1C_20150830T100016_N0500_R122_T33TUK_20231016T110421.SAFE',
#        'S2A_MSIL1C_20160506T100032_N0500_R122_T32TQR_20231027T050524.SAFE',
#        'S2A_MSIL1C_20160923T100022_N0500_R122_T32TQQ_20231031T001441.SAFE',
#        'S2A_MSIL1C_20170312T100021_N0500_R122_T32TQR_20231024T160932.SAFE',
#        'S2A_MSIL1C_20170312T100021_N0500_R122_T32TQQ_20231024T160932.SAFE',
#        'S2A_MSIL1C_20171008T100031_N0500_R122_T32TQQ_20231015T105525.SAFE',
#        'S2A_MSIL1C_20180605T100031_N0500_R122_T32TQR_20230809T084957.SAFE',
#        'S2A_MSIL1C_20180705T100031_N0500_R122_T32TQR_20230805T194837.SAFE',
#        'S2A_MSIL1C_20180804T100031_N0500_R122_T33TUK_20230807T083022.SAFE',
#        'S2A_MSIL1C_20190531T100031_N0500_R122_T32TQR_20221213T082018.SAFE',
#        'S2A_MSIL1C_20190630T100031_N0500_R122_T32TQR_20230723T095540.SAFE',
#        'S2A_MSIL1C_20190720T100031_N0500_R122_T33TUK_20230715T235221.SAFE',
#        'S2A_MSIL1C_20190819T100031_N0500_R122_T32TQR_20230719T223350.SAFE',
#        'S2A_MSIL1C_20190819T100031_N0500_R122_T33TUK_20230719T223350.SAFE',
#        'S2A_MSIL1C_20200525T100031_N0500_R122_T32TQR_20230509T083609.SAFE',
#        'S2A_MSIL1C_20200823T100031_N0500_R122_T32TQR_20230507T005454.SAFE',
#        'S2A_MSIL1C_20161126T094332_N0500_R036_T33SXC_20231025T160709.SAFE',
#        'S2A_MSIL1C_20181007T094031_N0500_R036_T33SXC_20230727T233522.SAFE',
#        'S2A_MSIL1C_20181106T094201_N0500_R036_T33SXC_20230727T210154.SAFE',
#        'S2A_MSIL1C_20160817T101032_N0500_R022_T32TQQ_20231026T121118.SAFE',
#        'S2A_MSIL1C_20170404T101021_N0500_R022_T33TUK_20231111T073007.SAFE',
#        'S2A_MSIL1C_20180906T101021_N0500_R022_T33TUK_20230712T073442.SAFE',
#        'S2A_MSIL1C_20180906T101021_N0500_R022_T32TQQ_20230802T221241.SAFE',
#        'S2A_MSIL1C_20190524T101031_N0500_R022_T33TUK_20221209T052220.SAFE',
#        'S2A_MSIL1C_20200319T101021_N0500_R022_T33TUK_20230628T195927.SAFE',
#        'S2A_MSIL1C_20200408T101021_N0500_R022_T32TQQ_20230420T020920.SAFE',
#        'S2A_MSIL1C_20210423T101021_N0500_R022_T33TUK_20230511T124905.SAFE',
#        'S2A_MSIL1C_20210423T101021_N0500_R022_T32TQQ_20230511T124905.SAFE',
#        'S2A_MSIL1C_20210811T101031_N0500_R022_T32TQQ_20230211T192458.SAFE',
#        'S2A_MSIL1C_20160804T100032_N0500_R122_T33TUK_20231026T150644.SAFE',
#        'S2A_MSIL1C_20170312T100021_N0500_R122_T33TUK_20231024T160932.SAFE',
#        'S2A_MSIL1C_20170521T100031_N0500_R122_T33TUK_20231113T203902.SAFE',
#        'S2A_MSIL1C_20180605T100031_N0500_R122_T33TUK_20230809T084957.SAFE',
#        'S2A_MSIL1C_20180725T100031_N0500_R122_T32TQQ_20230808T082127.SAFE',
#        'S2A_MSIL1C_20181013T100021_N0500_R122_T33TUK_20230718T053309.SAFE',
#        'S2A_MSIL1C_20181013T100021_N0500_R122_T32TQQ_20230718T053309.SAFE',
#        'S2A_MSIL1C_20190302T100021_N0500_R122_T33TUK_20221112T030944.SAFE',
#        'S2A_MSIL1C_20190322T100031_N0500_R122_T32TQQ_20221119T025646.SAFE',
#        'S2A_MSIL1C_20190322T100031_N0500_R122_T33TUK_20221119T025646.SAFE',
#        'S2A_MSIL1C_20190720T100031_N0500_R122_T32TQQ_20230715T235221.SAFE',
#        'S2A_MSIL1C_20191008T100031_N0500_R122_T32TQQ_20230613T122804.SAFE',
#        'S2A_MSIL1C_20200215T100111_N0500_R122_T32TQQ_20230625T052410.SAFE',
#        'S2A_MSIL1C_20200525T100031_N0500_R122_T33TUK_20230509T083609.SAFE',
#        'S2A_MSIL1C_20210331T100021_N0500_R122_T32TQQ_20230518T222256.SAFE',
#        'S2A_MSIL1C_20210331T100021_N0500_R122_T33TUK_20230518T222256.SAFE',
#        'S2A_MSIL1C_20150711T100006_N0500_R122_T33TUK_20231011T083658.SAFE',
#        'S2A_MSIL1C_20160824T100032_N0500_R122_T32TQR_20231026T160517.SAFE',
#        'S2A_MSIL1C_20160923T100022_N0500_R122_T32TQR_20231031T001441.SAFE',
#        'S2A_MSIL1C_20170220T100031_N0500_R122_T32TQQ_20231026T041810.SAFE',
#        'S2A_MSIL1C_20171008T100031_N0500_R122_T32TQR_20231015T105525.SAFE',
#        'S2A_MSIL1C_20180327T100031_N0500_R122_T32TQQ_20230727T063509.SAFE',
#        'S2A_MSIL1C_20180923T100021_N0500_R122_T32TQR_20230819T205944.SAFE',
#        'S2A_MSIL1C_20180923T100021_N0500_R122_T33TUK_20230819T205944.SAFE',
#        'S2A_MSIL1C_20200525T100031_N0500_R122_T33TUL_20230509T083609.SAFE',
#        'S2A_MSIL1C_20210331T100021_N0500_R122_T32TQR_20230518T222256.SAFE',
#        'S2A_MSIL1C_20210331T100021_N0500_R122_T33TUL_20230518T222256.SAFE',
#        'S2A_MSIL1C_20210420T100021_N0500_R122_T33TUK_20230522T132445.SAFE',
#        'S2A_MSIL1C_20210520T100031_N0500_R122_T32TQR_20230329T185738.SAFE',
#        'S2B_MSIL1C_20200403T100549_N0500_R022_T32TMN_20230530T162052.SAFE',
#        'S2B_MSIL1C_20190820T102029_N0500_R065_T32TMN_20230708T225122.SAFE',
#        'S2B_MSIL1C_20201013T101909_N0500_R065_T32TMN_20230414T162236.SAFE',
#        'S2B_MSIL1C_20201013T101909_N0500_R065_T32TMP_20230414T162236.SAFE',
#        'S2B_MSIL1C_20170718T101029_N0500_R022_T33TUK_20231006T230403.SAFE',
#        'S2B_MSIL1C_20170718T101029_N0500_R022_T32TQQ_20231006T230403.SAFE',
#        'S2B_MSIL1C_20170926T101009_N0500_R022_T32TQQ_20231012T073956.SAFE',
#        'S2B_MSIL1C_20180921T101019_N0500_R022_T32TQQ_20230819T195727.SAFE',
#        'S2B_MSIL1C_20181011T101019_N0500_R022_T33TUK_20230728T120715.SAFE',
#        'S2B_MSIL1C_20181031T101139_N0500_R022_T33TUK_20230706T042803.SAFE',
#        'S2B_MSIL1C_20181031T101139_N0500_R022_T32TQQ_20230706T042803.SAFE',
#        'S2B_MSIL1C_20190208T101159_N0500_R022_T33TUK_20221130T204816.SAFE',
#        'S2B_MSIL1C_20190228T101029_N0500_R022_T32TQQ_20230716T220857.SAFE',
#        'S2B_MSIL1C_20190330T101029_N0500_R022_T33TUK_20221111T151026.SAFE',
#        'S2B_MSIL1C_20190330T101029_N0500_R022_T32TQQ_20221111T151026.SAFE',
#        'S2B_MSIL1C_20190827T101029_N0500_R022_T32TQQ_20230720T200458.SAFE',
#        'S2B_MSIL1C_20190916T101029_N0500_R022_T32TQQ_20230627T003641.SAFE',
#        'S2B_MSIL1C_20200612T100559_N0500_R022_T32TQQ_20230327T041117.SAFE',
#        'S2B_MSIL1C_20200622T100559_N0500_R022_T32TQQ_20230501T013926.SAFE',
#        'S2B_MSIL1C_20201109T101239_N0500_R022_T32TQQ_20230403T202756.SAFE',
#        'S2B_MSIL1C_20210518T100559_N0500_R022_T32TQQ_20230222T092744.SAFE',
#        'S2B_MSIL1C_20180421T100029_N0500_R122_T32TQQ_20230905T042919.SAFE',
#        'S2B_MSIL1C_20180511T100029_N0500_R122_T32TQQ_20230902T184241.SAFE',
#        'S2B_MSIL1C_20180610T100029_N0500_R122_T32TQQ_20230820T172124.SAFE',
#        'S2B_MSIL1C_20180620T100029_N0500_R122_T33TUK_20230825T155032.SAFE',
#        'S2B_MSIL1C_20180630T100029_N0500_R122_T32TQQ_20230804T030054.SAFE',
#        'S2B_MSIL1C_20180730T100029_N0500_R122_T33TUK_20230723T022352.SAFE',
#        'S2B_MSIL1C_20180908T100019_N0500_R122_T32TQQ_20230708T021308.SAFE',
#        'S2B_MSIL1C_20180918T100019_N0500_R122_T32TQQ_20230823T180405.SAFE',
#        'S2B_MSIL1C_20180928T100019_N0500_R122_T32TQQ_20230729T233150.SAFE',
#        'S2B_MSIL1C_20190225T100029_N0500_R122_T32TQQ_20221213T055659.SAFE',
#        'S2B_MSIL1C_20190416T100029_N0500_R122_T33TUK_20221027T084300.SAFE',
#        'S2B_MSIL1C_20190516T100039_N0500_R122_T33TUK_20221220T162453.SAFE',
#        'S2B_MSIL1C_20190516T100039_N0500_R122_T32TQQ_20221220T162453.SAFE',
#        'S2B_MSIL1C_20190625T100039_N0500_R122_T32TQQ_20230508T054847.SAFE',
#        'S2B_MSIL1C_20190705T100039_N0500_R122_T32TQQ_20230718T022116.SAFE',
#        'S2B_MSIL1C_20190913T100029_N0500_R122_T33TUK_20230702T163422.SAFE',
#        'S2B_MSIL1C_20190913T100029_N0500_R122_T32TQQ_20230702T163422.SAFE',
#        'S2B_MSIL1C_20200220T100029_N0500_R122_T33TUK_20230612T014735.SAFE',
#        'S2B_MSIL1C_20200220T100029_N0500_R122_T32TQQ_20230612T014735.SAFE',
#        'S2B_MSIL1C_20200311T100029_N0500_R122_T32TQQ_20230419T193013.SAFE',
#        'S2B_MSIL1C_20200410T100029_N0500_R122_T33TUK_20230531T071614.SAFE',
#        'S2B_MSIL1C_20200619T100029_N0500_R122_T32TQQ_20231110T025716.SAFE',
#        'S2B_MSIL1C_20200709T100029_N0500_R122_T33TUK_20230612T010535.SAFE',
#        'S2B_MSIL1C_20200709T100029_N0500_R122_T32TQQ_20230612T010535.SAFE',
#        'S2B_MSIL1C_20200719T100029_N0500_R122_T32TQQ_20230629T225007.SAFE',
#        'S2B_MSIL1C_20200907T100029_N0500_R122_T32TQQ_20230416T071245.SAFE',
#        'S2B_MSIL1C_20210425T100019_N0500_R122_T32TQQ_20230511T201924.SAFE',
#        'S2B_MSIL1C_20210525T100029_N0500_R122_T32TQQ_20230226T012745.SAFE',
#        'S2B_MSIL1C_20210604T100029_N0500_R122_T32TQQ_20230320T102355.SAFE',
#        'S2B_MSIL1C_20171016T101009_N0500_R022_T32TQQ_20231013T084324.SAFE',
#        'S2B_MSIL1C_20190208T101159_N0500_R022_T32TQQ_20221130T204816.SAFE',
#        'S2B_MSIL1C_20190916T101029_N0500_R022_T33TUK_20230627T003641.SAFE',
#        'S2B_MSIL1C_20170705T100029_N0500_R122_T32TQR_20231005T022428.SAFE',
#        'S2B_MSIL1C_20170824T100019_N0500_R122_T33TUK_20231005T223432.SAFE',
#        'S2B_MSIL1C_20170824T100019_N0500_R122_T32TQQ_20231005T223432.SAFE',
#        'S2B_MSIL1C_20180610T100029_N0500_R122_T32TQR_20230820T172124.SAFE',
#        'S2B_MSIL1C_20180730T100029_N0500_R122_T32TQR_20230723T022352.SAFE',
#        'S2B_MSIL1C_20180730T100029_N0500_R122_T32TQQ_20230723T022352.SAFE',
#        'S2B_MSIL1C_20180908T100019_N0500_R122_T32TQR_20230708T021308.SAFE',
#        'S2B_MSIL1C_20180908T100019_N0500_R122_T33TUK_20230708T021308.SAFE',
#        'S2B_MSIL1C_20190406T100029_N0500_R122_T32TQR_20231115T010625.SAFE',
#        'S2B_MSIL1C_20190416T100029_N0500_R122_T32TQQ_20221027T084300.SAFE',
#        'S2B_MSIL1C_20200430T100019_N0500_R122_T32TQQ_20230521T212542.SAFE',
#        'S2B_MSIL1C_20200709T100029_N0500_R122_T32TQR_20230612T010535.SAFE',
#        'S2B_MSIL1C_20200828T100029_N0500_R122_T32TQQ_20230508T025101.SAFE',
#        'S2B_MSIL1C_20210425T100019_N0500_R122_T32TQR_20230511T201924.SAFE',
#        'S2B_MSIL1C_20210604T100029_N0500_R122_T32TQR_20230320T102355.SAFE',
#        'S2B_MSIL1C_20190331T094039_N0500_R036_T33SXC_20221116T010112.SAFE',
#        'S2B_MSIL1C_20200812T094039_N0500_R036_T33SXC_20230506T043001.SAFE',
#        'S2B_MSIL1C_20180822T101019_N0500_R022_T32TQQ_20230730T193531.SAFE',
#        'S2B_MSIL1C_20181011T101019_N0500_R022_T32TQQ_20230728T120715.SAFE',
#        'S2B_MSIL1C_20181021T101039_N0500_R022_T32TQQ_20230731T173332.SAFE',
#        'S2B_MSIL1C_20200622T100559_N0500_R022_T33TUK_20230501T013926.SAFE',
#        'S2B_MSIL1C_20200811T100559_N0500_R022_T33TUK_20230520T144508.SAFE',
#        'S2B_MSIL1C_20200821T100559_N0500_R022_T33TUK_20230512T135158.SAFE',
#        'S2B_MSIL1C_20200910T100559_N0500_R022_T33TUK_20230309T230357.SAFE',
#        'S2B_MSIL1C_20210329T100609_N0500_R022_T33TUK_20230531T233349.SAFE',
#        'S2B_MSIL1C_20210408T100549_N0500_R022_T32TQQ_20230512T121936.SAFE',
#        'S2B_MSIL1C_20180620T100029_N0500_R122_T32TQQ_20230825T155032.SAFE',
#        'S2B_MSIL1C_20180630T100029_N0500_R122_T33TUK_20230804T030054.SAFE',
#        'S2B_MSIL1C_20190705T100039_N0500_R122_T33TUK_20230718T022116.SAFE',
#        'S2B_MSIL1C_20200410T100029_N0500_R122_T32TQQ_20230531T071614.SAFE',
#        'S2B_MSIL1C_20200917T100029_N0500_R122_T32TQQ_20230422T014649.SAFE',
#        'S2B_MSIL1C_20201106T100219_N0500_R122_T33TUK_20230302T000153.SAFE',
#        'S2B_MSIL1C_20210425T100019_N0500_R122_T33TUK_20230511T201924.SAFE',
#        'S2B_MSIL1C_20180921T101019_N0500_R022_T32TQR_20230819T195727.SAFE',
#        'S2B_MSIL1C_20181031T101139_N0500_R022_T32TQR_20230706T042803.SAFE',
#        'S2B_MSIL1C_20190208T101159_N0500_R022_T32TQR_20221130T204816.SAFE',
#        'S2B_MSIL1C_20190228T101029_N0500_R022_T32TQR_20230716T220857.SAFE',
#        'S2B_MSIL1C_20200910T100559_N0500_R022_T32TQR_20230309T230357.SAFE',
#        'S2B_MSIL1C_20201109T101239_N0500_R022_T32TQR_20230403T202756.SAFE',
#        'S2B_MSIL1C_20170705T100029_N0500_R122_T33TUK_20231005T022428.SAFE',
#        'S2B_MSIL1C_20170824T100019_N0500_R122_T32TQR_20231005T223432.SAFE',
#        'S2B_MSIL1C_20180720T100029_N0500_R122_T32TQR_20230812T221245.SAFE',
#        'S2B_MSIL1C_20180720T100029_N0500_R122_T33TUL_20230812T221245.SAFE',
#        'S2B_MSIL1C_20181117T100259_N0500_R122_T32TQR_20230703T210755.SAFE',
#        'S2B_MSIL1C_20200619T100029_N0500_R122_T33TUK_20231110T025716.SAFE',
#        'S2B_MSIL1C_20200719T100029_N0500_R122_T32TQR_20230629T225007.SAFE',
#        'S2B_MSIL1C_20200808T100029_N0500_R122_T32TQQ_20230418T230937.SAFE',
#        'S2B_MSIL1C_20210425T100019_N0500_R122_T33TUL_20230511T201924.SAFE'],
#       dtype=object)
